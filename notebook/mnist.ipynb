# %% [markdown]
# <a href="https://colab.research.google.com/github/chokkan/deeplearning/blob/master/notebook/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Networks on MNIST
#
# This notebook explains various approaches for implementing neural networks that recognize digits on [MNIST](http://yann.lecun.com/exdb/mnist/) dataset.

# %% [markdown]
# ## Preparing the MNIST dataset
#
# Most deep learning frameworks provide APIs for loading famous datasets like MNIST (e.g., `torchvision.datasets.MNIST` in pytorch). The APIs are handy, but hide the important step for preparing a training data for a deep learning framework; when graduating from an example dataset to the real data, we must convert a training data of our interest into the data structure that is acceptable by a deep learning framework.
#
# The code below downloads the original distribution of the MNIST dataset on the Web, converts the dataset into `numpy` arrays, and saves the arrays as the file `mnist.npz` with keyword names.

# %%
import gzip
import sys
import struct
import urllib.request
import numpy as np

def read_image(fi):
    magic, n, rows, columns = struct.unpack(">IIII", fi.read(16))
    assert magic == 0x00000803
    assert rows == 28
    assert columns == 28
    rawbuffer = fi.read()
    assert len(rawbuffer) == n * rows * columns
    rawdata = np.frombuffer(rawbuffer, dtype='>u1', count=n*rows*columns)
    return rawdata.reshape(n, rows, columns).astype(np.float32) / 255.0

def read_label(fi):
    magic, n = struct.unpack(">II", fi.read(8))
    assert magic == 0x00000801
    rawbuffer = fi.read()
    assert len(rawbuffer) == n
    return np.frombuffer(rawbuffer, dtype='>u1', count=n)

def openurl_gzip(url):
    request = urllib.request.Request(
        url,
        headers={
            "Accept-Encoding": "gzip",
            "User-Agent": "Mozilla/5.0 (X11; U; Linux i686) Gecko/20071127 Firefox/2.0.0.11", 
        })
    response = urllib.request.urlopen(request)
    return gzip.GzipFile(fileobj=response, mode='rb')

if __name__ == '__main__':
    np.savez_compressed(
        'mnist',
        train_x=read_image(openurl_gzip('http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz')),
        train_y=read_label(openurl_gzip('http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz')),
        test_x=read_image(openurl_gzip('http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz')),
        test_y=read_label(openurl_gzip('http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz'))
    )

# %% [markdown]
# The file contains four numpy arrays (one tensor and array for each split of training and test sets) with the keywords:
#
# + `train_x`: $60000 \text{ (images)} \times 28 \text{ (y)} \times 28 \text{ (x)}$
# + `train_y`: $60000 \text{ (labels)}$
# + `test_x`: $10000 \text{ (images)} \times 28 \text{ (y)} \times 28 \text{ (x)}$
# + `test_y`: $10000 \text{ (labels)}$

# %%
import numpy as np
data = np.load('mnist.npz')

print(data['train_x'].shape, data['train_x'].dtype)
print(data['train_y'].shape, data['train_y'].dtype)
print(data['test_x'].shape, data['test_x'].dtype)
print(data['test_y'].shape, data['test_y'].dtype)
# Out:
# (60000, 28, 28) float32
# (60000,) uint8
# (10000, 28, 28) float32
# (10000,) uint8

# %% [markdown]
# ## Visualize the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Index number of an instance (change this to view another instance).
i = 1

data = np.load('mnist.npz')
image = data['train_x'][i]
label = data['train_y'][i]

print(label)
f, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(image, annot=True, fmt='.1f', square=True, cmap="YlGnBu")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# 0

# %% [markdown]
# ## Perceptron algorithm for single-layer neural network

# %%
import numpy as np

def image_to_vector(X):
    X = np.reshape(X, (len(X), -1))         # Flatten: (N x 28 x 28) -> (N x 784)
    return np.c_[X, np.ones(len(X))]        # Append 1: (N x 784) -> (N x 785)

data = np.load('mnist.npz')
Xtrain = image_to_vector(data['train_x'])   # (60000 x 785)
Ytrain = data['train_y']                    # (60000)
Xtest = image_to_vector(data['test_x'])     # (10000 x 785)
Ytest = data['test_y']                      # (10000)

W = np.random.randn(10, 28*28+1)            # (10 x 785)

eta = 0.001
for t in range(100):
    # Structured perceptron for updating weights.
    num_correct_train = 0
    for x, y in zip(Xtrain, Ytrain):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred != y:
            W[y] += x * eta
            W[y_pred] -= x * eta
        else:
            num_correct_train += 1

    # Evaluate and store the accuracy on the test set.
    num_correct_test = 0
    for x, y in zip(Xtest, Ytest):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred == y:
            num_correct_test += 1
    
    print('#{}: train_accuracy={:.4f}, test_accuracy={:.4f}'.format(
        t,
        float(num_correct_train) / len(Ytrain),
        float(num_correct_test) / len(Ytest)
    ))
# Out:
# #0: train_accuracy=0.5929, test_accuracy=0.7585
# #1: train_accuracy=0.7840, test_accuracy=0.8126
# #2: train_accuracy=0.8171, test_accuracy=0.8346
# #3: train_accuracy=0.8333, test_accuracy=0.8462
# #4: train_accuracy=0.8435, test_accuracy=0.8550
# #5: train_accuracy=0.8510, test_accuracy=0.8592
# #6: train_accuracy=0.8565, test_accuracy=0.8643
# #7: train_accuracy=0.8604, test_accuracy=0.8677
# #8: train_accuracy=0.8634, test_accuracy=0.8694
# #9: train_accuracy=0.8659, test_accuracy=0.8715
# #10: train_accuracy=0.8683, test_accuracy=0.8720
# #11: train_accuracy=0.8700, test_accuracy=0.8738
# #12: train_accuracy=0.8714, test_accuracy=0.8745
# #13: train_accuracy=0.8722, test_accuracy=0.8753
# #14: train_accuracy=0.8739, test_accuracy=0.8772
# #15: train_accuracy=0.8751, test_accuracy=0.8776
# #16: train_accuracy=0.8759, test_accuracy=0.8785
# #17: train_accuracy=0.8770, test_accuracy=0.8790
# #18: train_accuracy=0.8779, test_accuracy=0.8786
# #19: train_accuracy=0.8787, test_accuracy=0.8804
# #20: train_accuracy=0.8792, test_accuracy=0.8819
# #21: train_accuracy=0.8802, test_accuracy=0.8823
# #22: train_accuracy=0.8812, test_accuracy=0.8813
# #23: train_accuracy=0.8814, test_accuracy=0.8820
# #24: train_accuracy=0.8818, test_accuracy=0.8827
# #25: train_accuracy=0.8830, test_accuracy=0.8833
# #26: train_accuracy=0.8834, test_accuracy=0.8841
# #27: train_accuracy=0.8843, test_accuracy=0.8843
# #28: train_accuracy=0.8848, test_accuracy=0.8850
# #29: train_accuracy=0.8851, test_accuracy=0.8851
# #30: train_accuracy=0.8854, test_accuracy=0.8850
# #31: train_accuracy=0.8859, test_accuracy=0.8855
# #32: train_accuracy=0.8866, test_accuracy=0.8859
# #33: train_accuracy=0.8872, test_accuracy=0.8856
# #34: train_accuracy=0.8872, test_accuracy=0.8857
# #35: train_accuracy=0.8876, test_accuracy=0.8862
# #36: train_accuracy=0.8883, test_accuracy=0.8852
# #37: train_accuracy=0.8883, test_accuracy=0.8855
# #38: train_accuracy=0.8890, test_accuracy=0.8870
# #39: train_accuracy=0.8889, test_accuracy=0.8857
# #40: train_accuracy=0.8887, test_accuracy=0.8856
# #41: train_accuracy=0.8893, test_accuracy=0.8856
# #42: train_accuracy=0.8891, test_accuracy=0.8867
# #43: train_accuracy=0.8895, test_accuracy=0.8862
# #44: train_accuracy=0.8904, test_accuracy=0.8859
# #45: train_accuracy=0.8905, test_accuracy=0.8863
# #46: train_accuracy=0.8907, test_accuracy=0.8867
# #47: train_accuracy=0.8913, test_accuracy=0.8872
# #48: train_accuracy=0.8911, test_accuracy=0.8870
# #49: train_accuracy=0.8918, test_accuracy=0.8873
# #50: train_accuracy=0.8923, test_accuracy=0.8887
# #51: train_accuracy=0.8919, test_accuracy=0.8877
# #52: train_accuracy=0.8923, test_accuracy=0.8879
# #53: train_accuracy=0.8924, test_accuracy=0.8866
# #54: train_accuracy=0.8933, test_accuracy=0.8874
# #55: train_accuracy=0.8929, test_accuracy=0.8866
# #56: train_accuracy=0.8931, test_accuracy=0.8864
# #57: train_accuracy=0.8935, test_accuracy=0.8863
# #58: train_accuracy=0.8939, test_accuracy=0.8867
# #59: train_accuracy=0.8937, test_accuracy=0.8861
# #60: train_accuracy=0.8950, test_accuracy=0.8854
# #61: train_accuracy=0.8947, test_accuracy=0.8858
# #62: train_accuracy=0.8949, test_accuracy=0.8855
# #63: train_accuracy=0.8953, test_accuracy=0.8841
# #64: train_accuracy=0.8951, test_accuracy=0.8865
# #65: train_accuracy=0.8955, test_accuracy=0.8855
# #66: train_accuracy=0.8956, test_accuracy=0.8849
# #67: train_accuracy=0.8956, test_accuracy=0.8849
# #68: train_accuracy=0.8960, test_accuracy=0.8854
# #69: train_accuracy=0.8960, test_accuracy=0.8856
# #70: train_accuracy=0.8964, test_accuracy=0.8844
# #71: train_accuracy=0.8960, test_accuracy=0.8849
# #72: train_accuracy=0.8967, test_accuracy=0.8849
# #73: train_accuracy=0.8961, test_accuracy=0.8844
# #74: train_accuracy=0.8967, test_accuracy=0.8843
# #75: train_accuracy=0.8970, test_accuracy=0.8846
# #76: train_accuracy=0.8970, test_accuracy=0.8850
# #77: train_accuracy=0.8971, test_accuracy=0.8855
# #78: train_accuracy=0.8969, test_accuracy=0.8850
# #79: train_accuracy=0.8973, test_accuracy=0.8859
# #80: train_accuracy=0.8975, test_accuracy=0.8859
# #81: train_accuracy=0.8978, test_accuracy=0.8863
# #82: train_accuracy=0.8975, test_accuracy=0.8867
# #83: train_accuracy=0.8980, test_accuracy=0.8842
# #84: train_accuracy=0.8983, test_accuracy=0.8870
# #85: train_accuracy=0.8984, test_accuracy=0.8858
# #86: train_accuracy=0.8984, test_accuracy=0.8854
# #87: train_accuracy=0.8984, test_accuracy=0.8862
# #88: train_accuracy=0.8984, test_accuracy=0.8853
# #89: train_accuracy=0.8990, test_accuracy=0.8860
# #90: train_accuracy=0.8991, test_accuracy=0.8855
# #91: train_accuracy=0.8995, test_accuracy=0.8853
# #92: train_accuracy=0.8995, test_accuracy=0.8864
# #93: train_accuracy=0.9000, test_accuracy=0.8849
# #94: train_accuracy=0.9000, test_accuracy=0.8842
# #95: train_accuracy=0.9001, test_accuracy=0.8851
# #96: train_accuracy=0.9007, test_accuracy=0.8857
# #97: train_accuracy=0.9006, test_accuracy=0.8844
# #98: train_accuracy=0.9003, test_accuracy=0.8836
# #99: train_accuracy=0.9008, test_accuracy=0.8856

# %% [markdown]
# ## Stochastic gradient descent for single-layer neural network

# %%
import numpy as np

def softmax(x):
    # We subtract the maximum value to prevent overflow and underflow problems, 
    # (result of softmax are invariant even if we add/subtract a constant)
    ex = np.exp(x - np.max(x))  # Subtract such that the maximum value is one.
    return ex / ex.sum(axis=0)

def image_to_vector(X):
    X = np.reshape(X, (len(X), -1))     # Flatten: (N x 28 x 28) -> (N x 784)
    return np.c_[X, np.ones(len(X))]    # Append 1: (N x 784) -> (N x 785)

def label_to_onehot(Y, K):
    return np.eye(K)[Y]              # e.g., 3 -> [0, 0, 0, 1, 0, 0, 0, 0, 0]
    
data = np.load('mnist.npz')
Xtrain = image_to_vector(data['train_x'])       # (60000 x 785)
Ytrain = label_to_onehot(data['train_y'], 10)   # (60000 x 10)
Xtest = image_to_vector(data['test_x'])         # (10000 x 785)
Ytest = data['test_y']                          # (10000) (not one-hot encoding)

W = np.random.randn(10, 28*28+1)                # (10 x 785)

eta = 0.001
for t in range(100):
    loss = 0.
    num_correct_train = 0
    
    # Stochastic gradient descent.
    for x, y in zip(Xtrain, Ytrain):
        y_pred = softmax(np.dot(W, x))
        loss += -np.log(y_pred[np.argmax(y)])
        W += np.outer(eta * (y - y_pred), x)    # np.outer: out[i,j] = a[i]*b[j]
        if np.argmax(y_pred) == np.argmax(y):
            num_correct_train += 1
    
    # Evaluate and store the accuracy on the test set.
    num_correct_test = 0
    for x, y in zip(Xtest, Ytest):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred == y:
            num_correct_test += 1
            
    print('#{}: loss={:.2f}, train_accuracy={:.4f}, test_accuracy={:.4f}'.format(
        t,
        loss / len(Ytrain),
        float(num_correct_train) / len(Ytrain),
        float(num_correct_test) / len(Ytest)
    ))
# Out:
# #0: loss=2.56, train_accuracy=0.5988, test_accuracy=0.7737
# #1: loss=1.03, train_accuracy=0.7936, test_accuracy=0.8258
# #2: loss=0.83, train_accuracy=0.8280, test_accuracy=0.8459
# #3: loss=0.73, train_accuracy=0.8450, test_accuracy=0.8575
# #4: loss=0.67, train_accuracy=0.8548, test_accuracy=0.8658
# #5: loss=0.62, train_accuracy=0.8613, test_accuracy=0.8717
# #6: loss=0.59, train_accuracy=0.8669, test_accuracy=0.8749
# #7: loss=0.56, train_accuracy=0.8716, test_accuracy=0.8788
# #8: loss=0.54, train_accuracy=0.8751, test_accuracy=0.8811
# #9: loss=0.52, train_accuracy=0.8785, test_accuracy=0.8842
# #10: loss=0.50, train_accuracy=0.8811, test_accuracy=0.8878
# #11: loss=0.49, train_accuracy=0.8837, test_accuracy=0.8898
# #12: loss=0.47, train_accuracy=0.8862, test_accuracy=0.8909
# #13: loss=0.46, train_accuracy=0.8881, test_accuracy=0.8924
# #14: loss=0.45, train_accuracy=0.8898, test_accuracy=0.8934
# #15: loss=0.44, train_accuracy=0.8916, test_accuracy=0.8942
# #16: loss=0.43, train_accuracy=0.8933, test_accuracy=0.8955
# #17: loss=0.43, train_accuracy=0.8948, test_accuracy=0.8965
# #18: loss=0.42, train_accuracy=0.8955, test_accuracy=0.8966
# #19: loss=0.41, train_accuracy=0.8966, test_accuracy=0.8977
# #20: loss=0.41, train_accuracy=0.8982, test_accuracy=0.8984
# #21: loss=0.40, train_accuracy=0.8990, test_accuracy=0.8991
# #22: loss=0.40, train_accuracy=0.9002, test_accuracy=0.8999
# #23: loss=0.39, train_accuracy=0.9012, test_accuracy=0.9002
# #24: loss=0.39, train_accuracy=0.9021, test_accuracy=0.9006
# #25: loss=0.38, train_accuracy=0.9030, test_accuracy=0.9011
# #26: loss=0.38, train_accuracy=0.9039, test_accuracy=0.9016
# #27: loss=0.37, train_accuracy=0.9045, test_accuracy=0.9023
# #28: loss=0.37, train_accuracy=0.9051, test_accuracy=0.9026
# #29: loss=0.37, train_accuracy=0.9057, test_accuracy=0.9031
# #30: loss=0.36, train_accuracy=0.9063, test_accuracy=0.9033
# #31: loss=0.36, train_accuracy=0.9069, test_accuracy=0.9039
# #32: loss=0.36, train_accuracy=0.9077, test_accuracy=0.9043
# #33: loss=0.35, train_accuracy=0.9084, test_accuracy=0.9048
# #34: loss=0.35, train_accuracy=0.9091, test_accuracy=0.9051
# #35: loss=0.35, train_accuracy=0.9096, test_accuracy=0.9052
# #36: loss=0.35, train_accuracy=0.9102, test_accuracy=0.9059
# #37: loss=0.34, train_accuracy=0.9106, test_accuracy=0.9061
# #38: loss=0.34, train_accuracy=0.9112, test_accuracy=0.9064
# #39: loss=0.34, train_accuracy=0.9118, test_accuracy=0.9067
# #40: loss=0.34, train_accuracy=0.9123, test_accuracy=0.9071
# #41: loss=0.33, train_accuracy=0.9127, test_accuracy=0.9069
# #42: loss=0.33, train_accuracy=0.9130, test_accuracy=0.9068
# #43: loss=0.33, train_accuracy=0.9133, test_accuracy=0.9074
# #44: loss=0.33, train_accuracy=0.9134, test_accuracy=0.9076
# #45: loss=0.33, train_accuracy=0.9140, test_accuracy=0.9077
# #46: loss=0.32, train_accuracy=0.9143, test_accuracy=0.9079
# #47: loss=0.32, train_accuracy=0.9146, test_accuracy=0.9081
# #48: loss=0.32, train_accuracy=0.9150, test_accuracy=0.9085
# #49: loss=0.32, train_accuracy=0.9153, test_accuracy=0.9089
# #50: loss=0.32, train_accuracy=0.9157, test_accuracy=0.9093
# #51: loss=0.32, train_accuracy=0.9160, test_accuracy=0.9093
# #52: loss=0.32, train_accuracy=0.9164, test_accuracy=0.9098
# #53: loss=0.31, train_accuracy=0.9168, test_accuracy=0.9102
# #54: loss=0.31, train_accuracy=0.9170, test_accuracy=0.9104
# #55: loss=0.31, train_accuracy=0.9173, test_accuracy=0.9112
# #56: loss=0.31, train_accuracy=0.9174, test_accuracy=0.9112
# #57: loss=0.31, train_accuracy=0.9177, test_accuracy=0.9112
# #58: loss=0.31, train_accuracy=0.9180, test_accuracy=0.9118
# #59: loss=0.31, train_accuracy=0.9182, test_accuracy=0.9121
# #60: loss=0.30, train_accuracy=0.9184, test_accuracy=0.9125
# #61: loss=0.30, train_accuracy=0.9186, test_accuracy=0.9125
# #62: loss=0.30, train_accuracy=0.9189, test_accuracy=0.9125
# #63: loss=0.30, train_accuracy=0.9192, test_accuracy=0.9126
# #64: loss=0.30, train_accuracy=0.9196, test_accuracy=0.9127
# #65: loss=0.30, train_accuracy=0.9198, test_accuracy=0.9128
# #66: loss=0.30, train_accuracy=0.9200, test_accuracy=0.9132
# #67: loss=0.30, train_accuracy=0.9201, test_accuracy=0.9135
# #68: loss=0.30, train_accuracy=0.9203, test_accuracy=0.9139
# #69: loss=0.30, train_accuracy=0.9204, test_accuracy=0.9137
# #70: loss=0.29, train_accuracy=0.9207, test_accuracy=0.9139
# #71: loss=0.29, train_accuracy=0.9208, test_accuracy=0.9141
# #72: loss=0.29, train_accuracy=0.9211, test_accuracy=0.9144
# #73: loss=0.29, train_accuracy=0.9213, test_accuracy=0.9144
# #74: loss=0.29, train_accuracy=0.9214, test_accuracy=0.9145
# #75: loss=0.29, train_accuracy=0.9215, test_accuracy=0.9145
# #76: loss=0.29, train_accuracy=0.9217, test_accuracy=0.9147
# #77: loss=0.29, train_accuracy=0.9218, test_accuracy=0.9146
# #78: loss=0.29, train_accuracy=0.9220, test_accuracy=0.9149
# #79: loss=0.29, train_accuracy=0.9222, test_accuracy=0.9149
# #80: loss=0.29, train_accuracy=0.9224, test_accuracy=0.9152
# #81: loss=0.29, train_accuracy=0.9226, test_accuracy=0.9155
# #82: loss=0.29, train_accuracy=0.9228, test_accuracy=0.9157
# #83: loss=0.28, train_accuracy=0.9230, test_accuracy=0.9160
# #84: loss=0.28, train_accuracy=0.9234, test_accuracy=0.9157
# #85: loss=0.28, train_accuracy=0.9235, test_accuracy=0.9157
# #86: loss=0.28, train_accuracy=0.9235, test_accuracy=0.9158
# #87: loss=0.28, train_accuracy=0.9238, test_accuracy=0.9158
# #88: loss=0.28, train_accuracy=0.9240, test_accuracy=0.9161
# #89: loss=0.28, train_accuracy=0.9241, test_accuracy=0.9162
# #90: loss=0.28, train_accuracy=0.9242, test_accuracy=0.9159
# #91: loss=0.28, train_accuracy=0.9243, test_accuracy=0.9161
# #92: loss=0.28, train_accuracy=0.9244, test_accuracy=0.9163
# #93: loss=0.28, train_accuracy=0.9246, test_accuracy=0.9163
# #94: loss=0.28, train_accuracy=0.9246, test_accuracy=0.9162
# #95: loss=0.28, train_accuracy=0.9248, test_accuracy=0.9164
# #96: loss=0.28, train_accuracy=0.9249, test_accuracy=0.9166
# #97: loss=0.28, train_accuracy=0.9250, test_accuracy=0.9167
# #98: loss=0.28, train_accuracy=0.9252, test_accuracy=0.9172
# #99: loss=0.28, train_accuracy=0.9253, test_accuracy=0.9171

# %% [markdown]
# ## Training with pytorch

# %% [markdown]
# ### Activate TensorBoard
#
# Usage from PyTorch: https://pytorch.org/docs/stable/tensorboard.html

# %%
# Uncomment these lines when you use TensorBoard.
#%load_ext tensorboard
#%tensorboard --logdir ./runs/

# %% [markdown]
# ### Convert the numpy arrays into pytorch tensor

# %%
def create_dataset(x, y, flatten=False):
    if flatten:
        # Convert it into a matrix (N [samples], 28*28 [dims])
        xt = torch.from_numpy(x).view(len(x), -1)
    else:
        # Convert it into a 4D tensor (N [samples], 1 [ch], 28 [px], 28 [px])
        xt = torch.from_numpy(x).unsqueeze(1)
    yt = torch.from_numpy(y).long()
    return TensorDataset(xt, yt)

def test_model(model, loss_fn, test_loader, device):
    model.eval()

    loss = 0.
    num_correct = 0.
    for batch_idx, (x, y) in enumerate(test_loader):
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        loss += loss_fn(y_pred, y).item()
        _, predicted = torch.max(y_pred.data, 1)
        num_correct += (predicted == y).sum().item()

    model.train()
    loss /= len(test_loader.dataset)
    num_correct /= len(test_loader.dataset)
    return loss, num_correct

# %% [markdown]
# ### Single-layer neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

model = nn.Sequential()
model.add_module('fc1', nn.Linear(784, 10, bias=True))
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

writer = SummaryWriter(comment="single-layer")
for t in range(100):
    train_loss = 0.
    train_correct = 0
    
    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()
        
        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))
    
    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Record loss and accuracy values on the training and test sets.
    writer.add_scalars('loss', {'train': train_loss, 'test': test_loss}, t)
    writer.add_scalars('accuracy', {'train': train_correct, 'test': test_correct}, t)

    # Report progress (comment out the following line when you use TensorBoard).
    print('#{}: loss_test={:.4f}, loss_train={:.4f}, acc_test={:.4f}, acc_train={:.4f}'.format(
        t,
        test_loss,
        train_loss,
        test_correct,
        train_correct
    ))
writer.close()
# Out:
# Sequential(
#   (fc1): Linear(in_features=784, out_features=10, bias=True)
# )
# #0: loss_test=0.0163, loss_train=0.0086, acc_test=0.4824, acc_train=0.2829
# #1: loss_test=0.0148, loss_train=0.0077, acc_test=0.6887, acc_train=0.5932
# #2: loss_test=0.0135, loss_train=0.0070, acc_test=0.7480, acc_train=0.7152
# #3: loss_test=0.0124, loss_train=0.0065, acc_test=0.7709, acc_train=0.7529
# #4: loss_test=0.0115, loss_train=0.0060, acc_test=0.7826, acc_train=0.7698
# #5: loss_test=0.0107, loss_train=0.0056, acc_test=0.7951, acc_train=0.7815
# #6: loss_test=0.0101, loss_train=0.0052, acc_test=0.8015, acc_train=0.7895
# #7: loss_test=0.0095, loss_train=0.0049, acc_test=0.8077, acc_train=0.7966
# #8: loss_test=0.0090, loss_train=0.0047, acc_test=0.8126, acc_train=0.8021
# #9: loss_test=0.0086, loss_train=0.0045, acc_test=0.8171, acc_train=0.8065
# #10: loss_test=0.0082, loss_train=0.0043, acc_test=0.8218, acc_train=0.8113
# #11: loss_test=0.0079, loss_train=0.0041, acc_test=0.8252, acc_train=0.8159
# #12: loss_test=0.0076, loss_train=0.0039, acc_test=0.8283, acc_train=0.8200
# #13: loss_test=0.0074, loss_train=0.0038, acc_test=0.8301, acc_train=0.8225
# #14: loss_test=0.0071, loss_train=0.0037, acc_test=0.8326, acc_train=0.8255
# #15: loss_test=0.0069, loss_train=0.0036, acc_test=0.8352, acc_train=0.8279
# #16: loss_test=0.0067, loss_train=0.0035, acc_test=0.8385, acc_train=0.8302
# #17: loss_test=0.0066, loss_train=0.0034, acc_test=0.8409, acc_train=0.8322
# #18: loss_test=0.0064, loss_train=0.0033, acc_test=0.8422, acc_train=0.8345
# #19: loss_test=0.0063, loss_train=0.0032, acc_test=0.8444, acc_train=0.8365
# #20: loss_test=0.0061, loss_train=0.0032, acc_test=0.8463, acc_train=0.8382
# #21: loss_test=0.0060, loss_train=0.0031, acc_test=0.8476, acc_train=0.8397
# #22: loss_test=0.0059, loss_train=0.0031, acc_test=0.8492, acc_train=0.8410
# #23: loss_test=0.0058, loss_train=0.0030, acc_test=0.8511, acc_train=0.8423
# #24: loss_test=0.0057, loss_train=0.0030, acc_test=0.8526, acc_train=0.8438
# #25: loss_test=0.0056, loss_train=0.0029, acc_test=0.8539, acc_train=0.8451
# #26: loss_test=0.0055, loss_train=0.0029, acc_test=0.8551, acc_train=0.8464
# #27: loss_test=0.0054, loss_train=0.0028, acc_test=0.8568, acc_train=0.8477
# #28: loss_test=0.0053, loss_train=0.0028, acc_test=0.8584, acc_train=0.8487
# #29: loss_test=0.0053, loss_train=0.0027, acc_test=0.8595, acc_train=0.8498
# #30: loss_test=0.0052, loss_train=0.0027, acc_test=0.8608, acc_train=0.8510
# #31: loss_test=0.0051, loss_train=0.0027, acc_test=0.8619, acc_train=0.8518
# #32: loss_test=0.0051, loss_train=0.0026, acc_test=0.8624, acc_train=0.8527
# #33: loss_test=0.0050, loss_train=0.0026, acc_test=0.8632, acc_train=0.8535
# #34: loss_test=0.0050, loss_train=0.0026, acc_test=0.8645, acc_train=0.8542
# #35: loss_test=0.0049, loss_train=0.0026, acc_test=0.8651, acc_train=0.8553
# #36: loss_test=0.0049, loss_train=0.0025, acc_test=0.8660, acc_train=0.8562
# #37: loss_test=0.0048, loss_train=0.0025, acc_test=0.8670, acc_train=0.8569
# #38: loss_test=0.0048, loss_train=0.0025, acc_test=0.8676, acc_train=0.8578
# #39: loss_test=0.0047, loss_train=0.0025, acc_test=0.8683, acc_train=0.8583
# #40: loss_test=0.0047, loss_train=0.0024, acc_test=0.8689, acc_train=0.8590
# #41: loss_test=0.0046, loss_train=0.0024, acc_test=0.8698, acc_train=0.8598
# #42: loss_test=0.0046, loss_train=0.0024, acc_test=0.8707, acc_train=0.8604
# #43: loss_test=0.0046, loss_train=0.0024, acc_test=0.8714, acc_train=0.8609
# #44: loss_test=0.0045, loss_train=0.0024, acc_test=0.8719, acc_train=0.8615
# #45: loss_test=0.0045, loss_train=0.0023, acc_test=0.8733, acc_train=0.8620
# #46: loss_test=0.0044, loss_train=0.0023, acc_test=0.8741, acc_train=0.8627
# #47: loss_test=0.0044, loss_train=0.0023, acc_test=0.8746, acc_train=0.8633
# #48: loss_test=0.0044, loss_train=0.0023, acc_test=0.8749, acc_train=0.8640
# #49: loss_test=0.0044, loss_train=0.0023, acc_test=0.8758, acc_train=0.8645
# #50: loss_test=0.0043, loss_train=0.0023, acc_test=0.8762, acc_train=0.8651
# #51: loss_test=0.0043, loss_train=0.0022, acc_test=0.8765, acc_train=0.8658
# #52: loss_test=0.0043, loss_train=0.0022, acc_test=0.8766, acc_train=0.8659
# #53: loss_test=0.0042, loss_train=0.0022, acc_test=0.8766, acc_train=0.8665
# #54: loss_test=0.0042, loss_train=0.0022, acc_test=0.8772, acc_train=0.8669
# #55: loss_test=0.0042, loss_train=0.0022, acc_test=0.8774, acc_train=0.8674
# #56: loss_test=0.0042, loss_train=0.0022, acc_test=0.8775, acc_train=0.8679
# #57: loss_test=0.0041, loss_train=0.0022, acc_test=0.8780, acc_train=0.8682
# #58: loss_test=0.0041, loss_train=0.0021, acc_test=0.8782, acc_train=0.8686
# #59: loss_test=0.0041, loss_train=0.0021, acc_test=0.8785, acc_train=0.8690
# #60: loss_test=0.0041, loss_train=0.0021, acc_test=0.8787, acc_train=0.8697
# #61: loss_test=0.0040, loss_train=0.0021, acc_test=0.8791, acc_train=0.8699
# #62: loss_test=0.0040, loss_train=0.0021, acc_test=0.8795, acc_train=0.8703
# #63: loss_test=0.0040, loss_train=0.0021, acc_test=0.8795, acc_train=0.8708
# #64: loss_test=0.0040, loss_train=0.0021, acc_test=0.8796, acc_train=0.8712
# #65: loss_test=0.0040, loss_train=0.0021, acc_test=0.8799, acc_train=0.8717
# #66: loss_test=0.0040, loss_train=0.0021, acc_test=0.8801, acc_train=0.8720
# #67: loss_test=0.0039, loss_train=0.0021, acc_test=0.8803, acc_train=0.8724
# #68: loss_test=0.0039, loss_train=0.0020, acc_test=0.8807, acc_train=0.8727
# #69: loss_test=0.0039, loss_train=0.0020, acc_test=0.8811, acc_train=0.8729
# #70: loss_test=0.0039, loss_train=0.0020, acc_test=0.8809, acc_train=0.8734
# #71: loss_test=0.0039, loss_train=0.0020, acc_test=0.8812, acc_train=0.8738
# #72: loss_test=0.0038, loss_train=0.0020, acc_test=0.8814, acc_train=0.8741
# #73: loss_test=0.0038, loss_train=0.0020, acc_test=0.8814, acc_train=0.8744
# #74: loss_test=0.0038, loss_train=0.0020, acc_test=0.8815, acc_train=0.8745
# #75: loss_test=0.0038, loss_train=0.0020, acc_test=0.8816, acc_train=0.8748
# #76: loss_test=0.0038, loss_train=0.0020, acc_test=0.8821, acc_train=0.8750
# #77: loss_test=0.0038, loss_train=0.0020, acc_test=0.8826, acc_train=0.8753
# #78: loss_test=0.0038, loss_train=0.0020, acc_test=0.8826, acc_train=0.8754
# #79: loss_test=0.0037, loss_train=0.0020, acc_test=0.8832, acc_train=0.8759
# #80: loss_test=0.0037, loss_train=0.0019, acc_test=0.8838, acc_train=0.8762
# #81: loss_test=0.0037, loss_train=0.0019, acc_test=0.8841, acc_train=0.8765
# #82: loss_test=0.0037, loss_train=0.0019, acc_test=0.8843, acc_train=0.8767
# #83: loss_test=0.0037, loss_train=0.0019, acc_test=0.8843, acc_train=0.8769
# #84: loss_test=0.0037, loss_train=0.0019, acc_test=0.8843, acc_train=0.8771
# #85: loss_test=0.0037, loss_train=0.0019, acc_test=0.8844, acc_train=0.8772
# #86: loss_test=0.0037, loss_train=0.0019, acc_test=0.8844, acc_train=0.8775
# #87: loss_test=0.0036, loss_train=0.0019, acc_test=0.8846, acc_train=0.8778
# #88: loss_test=0.0036, loss_train=0.0019, acc_test=0.8845, acc_train=0.8781
# #89: loss_test=0.0036, loss_train=0.0019, acc_test=0.8848, acc_train=0.8783
# #90: loss_test=0.0036, loss_train=0.0019, acc_test=0.8848, acc_train=0.8786
# #91: loss_test=0.0036, loss_train=0.0019, acc_test=0.8853, acc_train=0.8788
# #92: loss_test=0.0036, loss_train=0.0019, acc_test=0.8860, acc_train=0.8790
# #93: loss_test=0.0036, loss_train=0.0019, acc_test=0.8863, acc_train=0.8794
# #94: loss_test=0.0036, loss_train=0.0019, acc_test=0.8864, acc_train=0.8795
# #95: loss_test=0.0036, loss_train=0.0019, acc_test=0.8864, acc_train=0.8797
# #96: loss_test=0.0035, loss_train=0.0019, acc_test=0.8863, acc_train=0.8800
# #97: loss_test=0.0035, loss_train=0.0018, acc_test=0.8867, acc_train=0.8802
# #98: loss_test=0.0035, loss_train=0.0018, acc_test=0.8871, acc_train=0.8803
# #99: loss_test=0.0035, loss_train=0.0018, acc_test=0.8873, acc_train=0.8805

# %% [markdown]
# ### Three-layer neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

model = nn.Sequential()
model.add_module('fc1',      nn.Linear(784, 256))
model.add_module('relu1',    nn.ReLU())
model.add_module('dropout1', nn.Dropout())
model.add_module('fc2',      nn.Linear(256, 256))
model.add_module('relu2',    nn.ReLU())
model.add_module('dropout2', nn.Dropout())
model.add_module('fc3',      nn.Linear(256, 10))
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

writer = SummaryWriter(comment="two-layer")
for t in range(100):
    train_loss = 0.
    train_correct = 0
    
    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()
        
        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))
    
    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Record loss and accuracy values on the training and test sets.
    writer.add_scalars('loss', {'train': train_loss, 'test': test_loss}, t)
    writer.add_scalars('accuracy', {'train': train_correct, 'test': test_correct}, t)

    # Report progress (comment out the following line when you use TensorBoard).
    print('#{}: loss_test={:.4f}, loss_train={:.4f}, acc_test={:.4f}, acc_train={:.4f}'.format(
        t,
        test_loss,
        train_loss,
        test_correct,
        train_correct
    ))

writer.close()
# Out:
# Sequential(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )
# #0: loss_test=0.0181, loss_train=0.0090, acc_test=0.1577, acc_train=0.1141
# #1: loss_test=0.0181, loss_train=0.0090, acc_test=0.1937, acc_train=0.1310
# #2: loss_test=0.0180, loss_train=0.0090, acc_test=0.2170, acc_train=0.1476
# #3: loss_test=0.0180, loss_train=0.0089, acc_test=0.2343, acc_train=0.1643
# #4: loss_test=0.0179, loss_train=0.0089, acc_test=0.2618, acc_train=0.1850
# #5: loss_test=0.0178, loss_train=0.0089, acc_test=0.2992, acc_train=0.2025
# #6: loss_test=0.0177, loss_train=0.0089, acc_test=0.3383, acc_train=0.2258
# #7: loss_test=0.0177, loss_train=0.0088, acc_test=0.3736, acc_train=0.2505
# #8: loss_test=0.0176, loss_train=0.0088, acc_test=0.4074, acc_train=0.2792
# #9: loss_test=0.0174, loss_train=0.0087, acc_test=0.4403, acc_train=0.3037
# #10: loss_test=0.0173, loss_train=0.0087, acc_test=0.4769, acc_train=0.3287
# #11: loss_test=0.0172, loss_train=0.0086, acc_test=0.5086, acc_train=0.3543
# #12: loss_test=0.0170, loss_train=0.0086, acc_test=0.5374, acc_train=0.3771
# #13: loss_test=0.0169, loss_train=0.0085, acc_test=0.5649, acc_train=0.3947
# #14: loss_test=0.0166, loss_train=0.0084, acc_test=0.5888, acc_train=0.4129
# #15: loss_test=0.0164, loss_train=0.0083, acc_test=0.6067, acc_train=0.4305
# #16: loss_test=0.0161, loss_train=0.0082, acc_test=0.6236, acc_train=0.4439
# #17: loss_test=0.0158, loss_train=0.0081, acc_test=0.6380, acc_train=0.4537
# #18: loss_test=0.0155, loss_train=0.0080, acc_test=0.6521, acc_train=0.4656
# #19: loss_test=0.0151, loss_train=0.0078, acc_test=0.6623, acc_train=0.4718
# #20: loss_test=0.0147, loss_train=0.0076, acc_test=0.6738, acc_train=0.4887
# #21: loss_test=0.0143, loss_train=0.0074, acc_test=0.6847, acc_train=0.4973
# #22: loss_test=0.0138, loss_train=0.0073, acc_test=0.6937, acc_train=0.5061
# #23: loss_test=0.0133, loss_train=0.0070, acc_test=0.7013, acc_train=0.5206
# #24: loss_test=0.0127, loss_train=0.0068, acc_test=0.7099, acc_train=0.5312
# #25: loss_test=0.0122, loss_train=0.0066, acc_test=0.7156, acc_train=0.5441
# #26: loss_test=0.0117, loss_train=0.0064, acc_test=0.7217, acc_train=0.5525
# #27: loss_test=0.0112, loss_train=0.0062, acc_test=0.7268, acc_train=0.5615
# #28: loss_test=0.0107, loss_train=0.0059, acc_test=0.7333, acc_train=0.5746
# #29: loss_test=0.0102, loss_train=0.0057, acc_test=0.7397, acc_train=0.5843
# #30: loss_test=0.0098, loss_train=0.0055, acc_test=0.7467, acc_train=0.5955
# #31: loss_test=0.0094, loss_train=0.0054, acc_test=0.7552, acc_train=0.6021
# #32: loss_test=0.0090, loss_train=0.0052, acc_test=0.7609, acc_train=0.6115
# #33: loss_test=0.0086, loss_train=0.0050, acc_test=0.7671, acc_train=0.6217
# #34: loss_test=0.0083, loss_train=0.0049, acc_test=0.7738, acc_train=0.6295
# #35: loss_test=0.0080, loss_train=0.0047, acc_test=0.7785, acc_train=0.6385
# #36: loss_test=0.0077, loss_train=0.0046, acc_test=0.7838, acc_train=0.6478
# #37: loss_test=0.0075, loss_train=0.0045, acc_test=0.7873, acc_train=0.6518
# #38: loss_test=0.0073, loss_train=0.0044, acc_test=0.7920, acc_train=0.6615
# #39: loss_test=0.0070, loss_train=0.0043, acc_test=0.7949, acc_train=0.6667
# #40: loss_test=0.0068, loss_train=0.0042, acc_test=0.7994, acc_train=0.6742
# #41: loss_test=0.0067, loss_train=0.0041, acc_test=0.8017, acc_train=0.6804
# #42: loss_test=0.0065, loss_train=0.0040, acc_test=0.8052, acc_train=0.6848
# #43: loss_test=0.0063, loss_train=0.0039, acc_test=0.8077, acc_train=0.6900
# #44: loss_test=0.0062, loss_train=0.0039, acc_test=0.8119, acc_train=0.6961
# #45: loss_test=0.0060, loss_train=0.0038, acc_test=0.8137, acc_train=0.6995
# #46: loss_test=0.0059, loss_train=0.0037, acc_test=0.8169, acc_train=0.7069
# #47: loss_test=0.0058, loss_train=0.0037, acc_test=0.8188, acc_train=0.7118
# #48: loss_test=0.0057, loss_train=0.0036, acc_test=0.8216, acc_train=0.7158
# #49: loss_test=0.0056, loss_train=0.0035, acc_test=0.8246, acc_train=0.7194
# #50: loss_test=0.0054, loss_train=0.0035, acc_test=0.8274, acc_train=0.7231
# #51: loss_test=0.0053, loss_train=0.0034, acc_test=0.8286, acc_train=0.7280
# #52: loss_test=0.0053, loss_train=0.0034, acc_test=0.8300, acc_train=0.7334
# #53: loss_test=0.0052, loss_train=0.0033, acc_test=0.8319, acc_train=0.7355
# #54: loss_test=0.0051, loss_train=0.0033, acc_test=0.8340, acc_train=0.7401
# #55: loss_test=0.0050, loss_train=0.0033, acc_test=0.8362, acc_train=0.7426
# #56: loss_test=0.0049, loss_train=0.0032, acc_test=0.8371, acc_train=0.7472
# #57: loss_test=0.0048, loss_train=0.0032, acc_test=0.8385, acc_train=0.7501
# #58: loss_test=0.0048, loss_train=0.0031, acc_test=0.8407, acc_train=0.7550
# #59: loss_test=0.0047, loss_train=0.0031, acc_test=0.8422, acc_train=0.7539
# #60: loss_test=0.0047, loss_train=0.0031, acc_test=0.8434, acc_train=0.7577
# #61: loss_test=0.0046, loss_train=0.0030, acc_test=0.8467, acc_train=0.7615
# #62: loss_test=0.0045, loss_train=0.0030, acc_test=0.8478, acc_train=0.7642
# #63: loss_test=0.0045, loss_train=0.0030, acc_test=0.8502, acc_train=0.7671
# #64: loss_test=0.0044, loss_train=0.0029, acc_test=0.8514, acc_train=0.7686
# #65: loss_test=0.0044, loss_train=0.0029, acc_test=0.8526, acc_train=0.7725
# #66: loss_test=0.0043, loss_train=0.0029, acc_test=0.8530, acc_train=0.7749
# #67: loss_test=0.0043, loss_train=0.0028, acc_test=0.8550, acc_train=0.7765
# #68: loss_test=0.0042, loss_train=0.0028, acc_test=0.8561, acc_train=0.7807
# #69: loss_test=0.0042, loss_train=0.0028, acc_test=0.8572, acc_train=0.7815
# #70: loss_test=0.0041, loss_train=0.0028, acc_test=0.8586, acc_train=0.7836
# #71: loss_test=0.0041, loss_train=0.0027, acc_test=0.8595, acc_train=0.7873
# #72: loss_test=0.0041, loss_train=0.0027, acc_test=0.8613, acc_train=0.7866
# #73: loss_test=0.0040, loss_train=0.0027, acc_test=0.8628, acc_train=0.7917
# #74: loss_test=0.0040, loss_train=0.0027, acc_test=0.8640, acc_train=0.7923
# #75: loss_test=0.0039, loss_train=0.0026, acc_test=0.8646, acc_train=0.7961
# #76: loss_test=0.0039, loss_train=0.0026, acc_test=0.8651, acc_train=0.7939
# #77: loss_test=0.0039, loss_train=0.0026, acc_test=0.8660, acc_train=0.7968
# #78: loss_test=0.0038, loss_train=0.0026, acc_test=0.8663, acc_train=0.7997
# #79: loss_test=0.0038, loss_train=0.0026, acc_test=0.8670, acc_train=0.8008
# #80: loss_test=0.0038, loss_train=0.0026, acc_test=0.8674, acc_train=0.8014
# #81: loss_test=0.0038, loss_train=0.0025, acc_test=0.8690, acc_train=0.8056
# #82: loss_test=0.0037, loss_train=0.0025, acc_test=0.8704, acc_train=0.8031
# #83: loss_test=0.0037, loss_train=0.0025, acc_test=0.8708, acc_train=0.8064
# #84: loss_test=0.0037, loss_train=0.0025, acc_test=0.8722, acc_train=0.8065
# #85: loss_test=0.0037, loss_train=0.0025, acc_test=0.8737, acc_train=0.8083
# #86: loss_test=0.0036, loss_train=0.0024, acc_test=0.8745, acc_train=0.8124
# #87: loss_test=0.0036, loss_train=0.0024, acc_test=0.8758, acc_train=0.8117
# #88: loss_test=0.0036, loss_train=0.0024, acc_test=0.8766, acc_train=0.8131
# #89: loss_test=0.0035, loss_train=0.0024, acc_test=0.8770, acc_train=0.8150
# #90: loss_test=0.0035, loss_train=0.0024, acc_test=0.8774, acc_train=0.8149
# #91: loss_test=0.0035, loss_train=0.0024, acc_test=0.8781, acc_train=0.8164
# #92: loss_test=0.0035, loss_train=0.0023, acc_test=0.8786, acc_train=0.8174
# #93: loss_test=0.0035, loss_train=0.0023, acc_test=0.8797, acc_train=0.8213
# #94: loss_test=0.0034, loss_train=0.0023, acc_test=0.8804, acc_train=0.8209
# #95: loss_test=0.0034, loss_train=0.0023, acc_test=0.8813, acc_train=0.8244
# #96: loss_test=0.0034, loss_train=0.0023, acc_test=0.8816, acc_train=0.8226
# #97: loss_test=0.0034, loss_train=0.0023, acc_test=0.8823, acc_train=0.8239
# #98: loss_test=0.0034, loss_train=0.0023, acc_test=0.8825, acc_train=0.8254
# #99: loss_test=0.0033, loss_train=0.0023, acc_test=0.8830, acc_train=0.8277

# %% [markdown]
# ### Convolutional Neural Network (CNN)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

class Flatten(torch.nn.Module):
    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        return x.view(-1, 512)

model = torch.nn.Sequential(
    torch.nn.Conv2d(1, 16, (5, 5)),
    torch.nn.MaxPool2d(2),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    torch.nn.Conv2d(16, 32, (5, 5)),
    torch.nn.MaxPool2d(2),    
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    Flatten(),
    torch.nn.Linear(512, 256),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    torch.nn.Linear(256, 10),
)
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'])
test_set = create_dataset(data['test_x'], data['test_y'])
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

writer = SummaryWriter(comment="CNN")
for t in range(100):
    train_loss = 0.
    train_correct = 0
    
    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()
        
        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))
    
    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Record loss and accuracy values on the training and test sets.
    writer.add_scalars('loss', {'train': train_loss, 'test': test_loss}, t)
    writer.add_scalars('accuracy', {'train': train_correct, 'test': test_correct}, t)

    # Report progress (comment out the following line when you use TensorBoard).
    print('#{}: loss_test={:.4f}, loss_train={:.4f}, acc_test={:.4f}, acc_train={:.4f}'.format(
        t,
        test_loss,
        train_loss,
        test_correct,
        train_correct
    ))

writer.close()
# Out:
# Sequential(
#   (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1))
#   (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Flatten()
#   (9): Linear(in_features=512, out_features=256, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.5, inplace=False)
#   (12): Linear(in_features=256, out_features=10, bias=True)
# )
# #0: loss_test=0.0182, loss_train=0.0090, acc_test=0.1278, acc_train=0.1154
# #1: loss_test=0.0181, loss_train=0.0090, acc_test=0.1461, acc_train=0.1228
# #2: loss_test=0.0181, loss_train=0.0090, acc_test=0.1782, acc_train=0.1292
# #3: loss_test=0.0181, loss_train=0.0090, acc_test=0.2275, acc_train=0.1371
# #4: loss_test=0.0180, loss_train=0.0090, acc_test=0.2727, acc_train=0.1465
# #5: loss_test=0.0180, loss_train=0.0089, acc_test=0.3033, acc_train=0.1597
# #6: loss_test=0.0179, loss_train=0.0089, acc_test=0.3273, acc_train=0.1699
# #7: loss_test=0.0178, loss_train=0.0089, acc_test=0.3586, acc_train=0.1844
# #8: loss_test=0.0178, loss_train=0.0088, acc_test=0.3924, acc_train=0.1970
# #9: loss_test=0.0176, loss_train=0.0088, acc_test=0.4261, acc_train=0.2125
# #10: loss_test=0.0175, loss_train=0.0088, acc_test=0.4566, acc_train=0.2294
# #11: loss_test=0.0173, loss_train=0.0087, acc_test=0.4863, acc_train=0.2506
# #12: loss_test=0.0170, loss_train=0.0086, acc_test=0.5120, acc_train=0.2645
# #13: loss_test=0.0166, loss_train=0.0085, acc_test=0.5329, acc_train=0.2893
# #14: loss_test=0.0162, loss_train=0.0083, acc_test=0.5509, acc_train=0.3088
# #15: loss_test=0.0155, loss_train=0.0081, acc_test=0.5728, acc_train=0.3286
# #16: loss_test=0.0147, loss_train=0.0078, acc_test=0.6097, acc_train=0.3539
# #17: loss_test=0.0137, loss_train=0.0075, acc_test=0.6420, acc_train=0.3743
# #18: loss_test=0.0127, loss_train=0.0071, acc_test=0.6738, acc_train=0.4003
# #19: loss_test=0.0116, loss_train=0.0067, acc_test=0.7003, acc_train=0.4321
# #20: loss_test=0.0106, loss_train=0.0064, acc_test=0.7218, acc_train=0.4591
# #21: loss_test=0.0097, loss_train=0.0060, acc_test=0.7364, acc_train=0.4854
# #22: loss_test=0.0088, loss_train=0.0057, acc_test=0.7524, acc_train=0.5163
# #23: loss_test=0.0081, loss_train=0.0054, acc_test=0.7636, acc_train=0.5408
# #24: loss_test=0.0075, loss_train=0.0051, acc_test=0.7740, acc_train=0.5651
# #25: loss_test=0.0070, loss_train=0.0048, acc_test=0.7846, acc_train=0.5842
# #26: loss_test=0.0066, loss_train=0.0047, acc_test=0.7961, acc_train=0.5981
# #27: loss_test=0.0062, loss_train=0.0044, acc_test=0.8070, acc_train=0.6199
# #28: loss_test=0.0059, loss_train=0.0043, acc_test=0.8158, acc_train=0.6302
# #29: loss_test=0.0056, loss_train=0.0041, acc_test=0.8221, acc_train=0.6473
# #30: loss_test=0.0054, loss_train=0.0040, acc_test=0.8287, acc_train=0.6566
# #31: loss_test=0.0052, loss_train=0.0039, acc_test=0.8348, acc_train=0.6655
# #32: loss_test=0.0050, loss_train=0.0038, acc_test=0.8391, acc_train=0.6779
# #33: loss_test=0.0048, loss_train=0.0037, acc_test=0.8455, acc_train=0.6861
# #34: loss_test=0.0047, loss_train=0.0036, acc_test=0.8522, acc_train=0.6916
# #35: loss_test=0.0045, loss_train=0.0035, acc_test=0.8572, acc_train=0.7016
# #36: loss_test=0.0044, loss_train=0.0034, acc_test=0.8621, acc_train=0.7106
# #37: loss_test=0.0043, loss_train=0.0033, acc_test=0.8667, acc_train=0.7174
# #38: loss_test=0.0041, loss_train=0.0033, acc_test=0.8712, acc_train=0.7251
# #39: loss_test=0.0040, loss_train=0.0032, acc_test=0.8740, acc_train=0.7303
# #40: loss_test=0.0039, loss_train=0.0031, acc_test=0.8771, acc_train=0.7359
# #41: loss_test=0.0038, loss_train=0.0031, acc_test=0.8786, acc_train=0.7392
# #42: loss_test=0.0037, loss_train=0.0030, acc_test=0.8820, acc_train=0.7478
# #43: loss_test=0.0037, loss_train=0.0030, acc_test=0.8853, acc_train=0.7491
# #44: loss_test=0.0036, loss_train=0.0029, acc_test=0.8873, acc_train=0.7538
# #45: loss_test=0.0035, loss_train=0.0029, acc_test=0.8890, acc_train=0.7610
# #46: loss_test=0.0034, loss_train=0.0028, acc_test=0.8909, acc_train=0.7662
# #47: loss_test=0.0033, loss_train=0.0028, acc_test=0.8937, acc_train=0.7671
# #48: loss_test=0.0033, loss_train=0.0027, acc_test=0.8966, acc_train=0.7719
# #49: loss_test=0.0032, loss_train=0.0027, acc_test=0.8984, acc_train=0.7759
# #50: loss_test=0.0031, loss_train=0.0026, acc_test=0.8995, acc_train=0.7814
# #51: loss_test=0.0031, loss_train=0.0026, acc_test=0.9013, acc_train=0.7856
# #52: loss_test=0.0030, loss_train=0.0026, acc_test=0.9048, acc_train=0.7887
# #53: loss_test=0.0030, loss_train=0.0025, acc_test=0.9055, acc_train=0.7929
# #54: loss_test=0.0029, loss_train=0.0025, acc_test=0.9068, acc_train=0.7929
# #55: loss_test=0.0029, loss_train=0.0025, acc_test=0.9080, acc_train=0.7980
# #56: loss_test=0.0028, loss_train=0.0024, acc_test=0.9089, acc_train=0.7977
# #57: loss_test=0.0028, loss_train=0.0024, acc_test=0.9113, acc_train=0.8032
# #58: loss_test=0.0027, loss_train=0.0023, acc_test=0.9122, acc_train=0.8055
# #59: loss_test=0.0027, loss_train=0.0023, acc_test=0.9142, acc_train=0.8098
# #60: loss_test=0.0026, loss_train=0.0023, acc_test=0.9145, acc_train=0.8109
# #61: loss_test=0.0026, loss_train=0.0023, acc_test=0.9164, acc_train=0.8120
# #62: loss_test=0.0026, loss_train=0.0023, acc_test=0.9170, acc_train=0.8158
# #63: loss_test=0.0025, loss_train=0.0022, acc_test=0.9188, acc_train=0.8175
# #64: loss_test=0.0025, loss_train=0.0022, acc_test=0.9186, acc_train=0.8188
# #65: loss_test=0.0025, loss_train=0.0022, acc_test=0.9198, acc_train=0.8222
# #66: loss_test=0.0024, loss_train=0.0022, acc_test=0.9207, acc_train=0.8236
# #67: loss_test=0.0024, loss_train=0.0021, acc_test=0.9217, acc_train=0.8281
# #68: loss_test=0.0023, loss_train=0.0021, acc_test=0.9225, acc_train=0.8286
# #69: loss_test=0.0023, loss_train=0.0021, acc_test=0.9224, acc_train=0.8304
# #70: loss_test=0.0023, loss_train=0.0021, acc_test=0.9240, acc_train=0.8319
# #71: loss_test=0.0023, loss_train=0.0020, acc_test=0.9242, acc_train=0.8365
# #72: loss_test=0.0022, loss_train=0.0020, acc_test=0.9247, acc_train=0.8375
# #73: loss_test=0.0022, loss_train=0.0020, acc_test=0.9265, acc_train=0.8377
# #74: loss_test=0.0022, loss_train=0.0020, acc_test=0.9266, acc_train=0.8379
# #75: loss_test=0.0021, loss_train=0.0020, acc_test=0.9277, acc_train=0.8391
# #76: loss_test=0.0021, loss_train=0.0019, acc_test=0.9277, acc_train=0.8437
# #77: loss_test=0.0021, loss_train=0.0019, acc_test=0.9286, acc_train=0.8428
# #78: loss_test=0.0021, loss_train=0.0019, acc_test=0.9296, acc_train=0.8472
# #79: loss_test=0.0021, loss_train=0.0019, acc_test=0.9301, acc_train=0.8450
# #80: loss_test=0.0020, loss_train=0.0019, acc_test=0.9315, acc_train=0.8476
# #81: loss_test=0.0020, loss_train=0.0019, acc_test=0.9320, acc_train=0.8501
# #82: loss_test=0.0020, loss_train=0.0018, acc_test=0.9330, acc_train=0.8503
# #83: loss_test=0.0020, loss_train=0.0018, acc_test=0.9334, acc_train=0.8509
# #84: loss_test=0.0019, loss_train=0.0018, acc_test=0.9345, acc_train=0.8529
# #85: loss_test=0.0019, loss_train=0.0018, acc_test=0.9343, acc_train=0.8542
# #86: loss_test=0.0019, loss_train=0.0018, acc_test=0.9348, acc_train=0.8556
# #87: loss_test=0.0019, loss_train=0.0018, acc_test=0.9353, acc_train=0.8562
# #88: loss_test=0.0019, loss_train=0.0018, acc_test=0.9361, acc_train=0.8579
# #89: loss_test=0.0019, loss_train=0.0017, acc_test=0.9364, acc_train=0.8596
# #90: loss_test=0.0018, loss_train=0.0017, acc_test=0.9371, acc_train=0.8598
# #91: loss_test=0.0018, loss_train=0.0017, acc_test=0.9371, acc_train=0.8628
# #92: loss_test=0.0018, loss_train=0.0017, acc_test=0.9381, acc_train=0.8627
# #93: loss_test=0.0018, loss_train=0.0017, acc_test=0.9380, acc_train=0.8639
# #94: loss_test=0.0018, loss_train=0.0017, acc_test=0.9389, acc_train=0.8650
# #95: loss_test=0.0018, loss_train=0.0017, acc_test=0.9396, acc_train=0.8657
# #96: loss_test=0.0017, loss_train=0.0017, acc_test=0.9396, acc_train=0.8659
# #97: loss_test=0.0017, loss_train=0.0016, acc_test=0.9394, acc_train=0.8682
# #98: loss_test=0.0017, loss_train=0.0017, acc_test=0.9403, acc_train=0.8668
# #99: loss_test=0.0017, loss_train=0.0016, acc_test=0.9403, acc_train=0.8695
