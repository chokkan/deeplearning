# %% [markdown]
# <a href="https://colab.research.google.com/github/chokkan/deeplearning/blob/master/notebook/mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neural Networks on MNIST
#
# This notebook explains various approaches for implementing neural networks that recognize digits on [MNIST](http://yann.lecun.com/exdb/mnist/) dataset.

# %% [markdown]
# ## Preparing the MNIST dataset
#
# Most deep learning frameworks provide APIs for loading famous datasets like MNIST (e.g., `torchvision.datasets.MNIST` in pytorch). The APIs are handy, but hide the important step for preparing a training data for a deep learning framework; when graduating from an example dataset to the real data, we must convert a training data of our interest into the data structure that is acceptable by a deep learning framework.
#
# The code below downloads the original distribution of the MNIST dataset on the Web, converts the dataset into `numpy` arrays, and saves the arrays as the file `mnist.npz` with keyword names.

# %%
import gzip
import sys
import struct
import urllib.request
import numpy as np

def read_image(fi):
    magic, n, rows, columns = struct.unpack(">IIII", fi.read(16))
    assert magic == 0x00000803
    assert rows == 28
    assert columns == 28
    rawbuffer = fi.read()
    assert len(rawbuffer) == n * rows * columns
    rawdata = np.frombuffer(rawbuffer, dtype='>u1', count=n*rows*columns)
    return rawdata.reshape(n, rows, columns).astype(np.float32) / 255.0

def read_label(fi):
    magic, n = struct.unpack(">II", fi.read(8))
    assert magic == 0x00000801
    rawbuffer = fi.read()
    assert len(rawbuffer) == n
    return np.frombuffer(rawbuffer, dtype='>u1', count=n)

def openurl_gzip(url):
    request = urllib.request.Request(
        url,
        headers={
            "Accept-Encoding": "gzip",
            "User-Agent": "Mozilla/5.0 (X11; U; Linux i686) Gecko/20071127 Firefox/2.0.0.11",
        })
    response = urllib.request.urlopen(request)
    return gzip.GzipFile(fileobj=response, mode='rb')

if __name__ == '__main__':
    np.savez_compressed(
        'mnist',
        train_x=read_image(openurl_gzip('https://raw.githubusercontent.com/fgnt/mnist/master/train-images-idx3-ubyte.gz')),
        train_y=read_label(openurl_gzip('https://raw.githubusercontent.com/fgnt/mnist/master/train-labels-idx1-ubyte.gz')),
        test_x=read_image(openurl_gzip('https://raw.githubusercontent.com/fgnt/mnist/master/t10k-images-idx3-ubyte.gz')),
        test_y=read_label(openurl_gzip('https://raw.githubusercontent.com/fgnt/mnist/master/t10k-labels-idx1-ubyte.gz'))
    )

# %% [markdown]
# The file contains four numpy arrays (one tensor and array for each split of training and test sets) with the keywords:
#
# + `train_x`: $60000 \text{ (images)} \times 28 \text{ (y)} \times 28 \text{ (x)}$
# + `train_y`: $60000 \text{ (labels)}$
# + `test_x`: $10000 \text{ (images)} \times 28 \text{ (y)} \times 28 \text{ (x)}$
# + `test_y`: $10000 \text{ (labels)}$

# %%
import numpy as np
data = np.load('mnist.npz')

print(data['train_x'].shape, data['train_x'].dtype)
print(data['train_y'].shape, data['train_y'].dtype)
print(data['test_x'].shape, data['test_x'].dtype)
print(data['test_y'].shape, data['test_y'].dtype)
# Out:
# (60000, 28, 28) float32
# (60000,) uint8
# (10000, 28, 28) float32
# (10000,) uint8

# %% [markdown]
# ## Visualize the dataset

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Index number of an instance (change this to view another instance).
i = 1

data = np.load('mnist.npz')
image = data['train_x'][i]
label = data['train_y'][i]

print(label)
f, ax = plt.subplots(figsize=(16, 16))
sns.heatmap(image, annot=True, fmt='.1f', square=True, cmap="YlGnBu")
plt.show()
# Out:
# 0

# %% [markdown]
# ## Perceptron algorithm for single-layer neural network

# %%
import numpy as np

def image_to_vector(X):
    X = np.reshape(X, (len(X), -1))         # Flatten: (N x 28 x 28) -> (N x 784)
    return np.c_[X, np.ones(len(X))]        # Append 1: (N x 784) -> (N x 785)

data = np.load('mnist.npz')
Xtrain = image_to_vector(data['train_x'])   # (60000 x 785)
Ytrain = data['train_y']                    # (60000)
Xtest = image_to_vector(data['test_x'])     # (10000 x 785)
Ytest = data['test_y']                      # (10000)

W = np.random.randn(10, 28*28+1)            # (10 x 785)

eta = 0.001
for t in range(100):
    # Structured perceptron for updating weights.
    num_correct_train = 0
    for x, y in zip(Xtrain, Ytrain):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred != y:
            W[y] += x * eta
            W[y_pred] -= x * eta
        else:
            num_correct_train += 1

    # Evaluate and store the accuracy on the test set.
    num_correct_test = 0
    for x, y in zip(Xtest, Ytest):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred == y:
            num_correct_test += 1

    print('#{}: train_accuracy={:.4f}, test_accuracy={:.4f}'.format(
        t,
        float(num_correct_train) / len(Ytrain),
        float(num_correct_test) / len(Ytest)
    ))
# Out:
# #0: train_accuracy=0.5814, test_accuracy=0.7495
# #1: train_accuracy=0.7741, test_accuracy=0.8120
# #2: train_accuracy=0.8146, test_accuracy=0.8355
# #3: train_accuracy=0.8333, test_accuracy=0.8498
# #4: train_accuracy=0.8458, test_accuracy=0.8568
# #5: train_accuracy=0.8530, test_accuracy=0.8601
# #6: train_accuracy=0.8583, test_accuracy=0.8657
# #7: train_accuracy=0.8628, test_accuracy=0.8678
# #8: train_accuracy=0.8662, test_accuracy=0.8705
# #9: train_accuracy=0.8686, test_accuracy=0.8730
# #10: train_accuracy=0.8709, test_accuracy=0.8739
# #11: train_accuracy=0.8728, test_accuracy=0.8753
# #12: train_accuracy=0.8747, test_accuracy=0.8755
# #13: train_accuracy=0.8763, test_accuracy=0.8760
# #14: train_accuracy=0.8775, test_accuracy=0.8764
# #15: train_accuracy=0.8783, test_accuracy=0.8781
# #16: train_accuracy=0.8795, test_accuracy=0.8796
# #17: train_accuracy=0.8807, test_accuracy=0.8798
# #18: train_accuracy=0.8815, test_accuracy=0.8794
# #19: train_accuracy=0.8820, test_accuracy=0.8802
# #20: train_accuracy=0.8832, test_accuracy=0.8812
# #21: train_accuracy=0.8838, test_accuracy=0.8809
# #22: train_accuracy=0.8842, test_accuracy=0.8806
# #23: train_accuracy=0.8850, test_accuracy=0.8806
# #24: train_accuracy=0.8859, test_accuracy=0.8798
# #25: train_accuracy=0.8861, test_accuracy=0.8823
# #26: train_accuracy=0.8867, test_accuracy=0.8819
# #27: train_accuracy=0.8873, test_accuracy=0.8824
# #28: train_accuracy=0.8879, test_accuracy=0.8822
# #29: train_accuracy=0.8882, test_accuracy=0.8821
# #30: train_accuracy=0.8884, test_accuracy=0.8818
# #31: train_accuracy=0.8888, test_accuracy=0.8824
# #32: train_accuracy=0.8893, test_accuracy=0.8838
# #33: train_accuracy=0.8893, test_accuracy=0.8834
# #34: train_accuracy=0.8899, test_accuracy=0.8834
# #35: train_accuracy=0.8900, test_accuracy=0.8828
# #36: train_accuracy=0.8912, test_accuracy=0.8836
# #37: train_accuracy=0.8906, test_accuracy=0.8841
# #38: train_accuracy=0.8904, test_accuracy=0.8845
# #39: train_accuracy=0.8908, test_accuracy=0.8839
# #40: train_accuracy=0.8912, test_accuracy=0.8840
# #41: train_accuracy=0.8912, test_accuracy=0.8838
# #42: train_accuracy=0.8918, test_accuracy=0.8853
# #43: train_accuracy=0.8916, test_accuracy=0.8850
# #44: train_accuracy=0.8921, test_accuracy=0.8855
# #45: train_accuracy=0.8929, test_accuracy=0.8855
# #46: train_accuracy=0.8929, test_accuracy=0.8849
# #47: train_accuracy=0.8929, test_accuracy=0.8859
# #48: train_accuracy=0.8931, test_accuracy=0.8857
# #49: train_accuracy=0.8931, test_accuracy=0.8868
# #50: train_accuracy=0.8933, test_accuracy=0.8865
# #51: train_accuracy=0.8940, test_accuracy=0.8863
# #52: train_accuracy=0.8940, test_accuracy=0.8857
# #53: train_accuracy=0.8942, test_accuracy=0.8860
# #54: train_accuracy=0.8945, test_accuracy=0.8867
# #55: train_accuracy=0.8953, test_accuracy=0.8868
# #56: train_accuracy=0.8955, test_accuracy=0.8853
# #57: train_accuracy=0.8948, test_accuracy=0.8860
# #58: train_accuracy=0.8954, test_accuracy=0.8851
# #59: train_accuracy=0.8956, test_accuracy=0.8855
# #60: train_accuracy=0.8957, test_accuracy=0.8846
# #61: train_accuracy=0.8958, test_accuracy=0.8834
# #62: train_accuracy=0.8961, test_accuracy=0.8850
# #63: train_accuracy=0.8963, test_accuracy=0.8848
# #64: train_accuracy=0.8965, test_accuracy=0.8843
# #65: train_accuracy=0.8967, test_accuracy=0.8843
# #66: train_accuracy=0.8966, test_accuracy=0.8833
# #67: train_accuracy=0.8968, test_accuracy=0.8851
# #68: train_accuracy=0.8966, test_accuracy=0.8843
# #69: train_accuracy=0.8969, test_accuracy=0.8832
# #70: train_accuracy=0.8975, test_accuracy=0.8833
# #71: train_accuracy=0.8972, test_accuracy=0.8827
# #72: train_accuracy=0.8974, test_accuracy=0.8843
# #73: train_accuracy=0.8977, test_accuracy=0.8835
# #74: train_accuracy=0.8976, test_accuracy=0.8836
# #75: train_accuracy=0.8978, test_accuracy=0.8839
# #76: train_accuracy=0.8983, test_accuracy=0.8831
# #77: train_accuracy=0.8985, test_accuracy=0.8833
# #78: train_accuracy=0.8980, test_accuracy=0.8852
# #79: train_accuracy=0.8986, test_accuracy=0.8842
# #80: train_accuracy=0.8985, test_accuracy=0.8839
# #81: train_accuracy=0.8985, test_accuracy=0.8837
# #82: train_accuracy=0.8986, test_accuracy=0.8841
# #83: train_accuracy=0.8990, test_accuracy=0.8850
# #84: train_accuracy=0.8989, test_accuracy=0.8855
# #85: train_accuracy=0.8989, test_accuracy=0.8834
# #86: train_accuracy=0.8993, test_accuracy=0.8853
# #87: train_accuracy=0.8991, test_accuracy=0.8849
# #88: train_accuracy=0.8992, test_accuracy=0.8845
# #89: train_accuracy=0.8993, test_accuracy=0.8846
# #90: train_accuracy=0.8996, test_accuracy=0.8850
# #91: train_accuracy=0.8991, test_accuracy=0.8845
# #92: train_accuracy=0.8996, test_accuracy=0.8845
# #93: train_accuracy=0.8999, test_accuracy=0.8839
# #94: train_accuracy=0.8996, test_accuracy=0.8844
# #95: train_accuracy=0.9001, test_accuracy=0.8854
# #96: train_accuracy=0.8996, test_accuracy=0.8855
# #97: train_accuracy=0.9003, test_accuracy=0.8845
# #98: train_accuracy=0.9007, test_accuracy=0.8851
# #99: train_accuracy=0.9001, test_accuracy=0.8859

# %% [markdown]
# ## Stochastic gradient descent for single-layer neural network

# %%
import numpy as np

def softmax(x):
    # We subtract the maximum value to prevent overflow and underflow problems,
    # (result of softmax are invariant even if we add/subtract a constant)
    ex = np.exp(x - np.max(x))  # Subtract such that the maximum value is one.
    return ex / ex.sum(axis=0)

def image_to_vector(X):
    X = np.reshape(X, (len(X), -1))     # Flatten: (N x 28 x 28) -> (N x 784)
    return np.c_[X, np.ones(len(X))]    # Append 1: (N x 784) -> (N x 785)

def label_to_onehot(Y, K):
    return np.eye(K)[Y]              # e.g., 3 -> [0, 0, 0, 1, 0, 0, 0, 0, 0]

data = np.load('mnist.npz')
Xtrain = image_to_vector(data['train_x'])       # (60000 x 785)
Ytrain = label_to_onehot(data['train_y'], 10)   # (60000 x 10)
Xtest = image_to_vector(data['test_x'])         # (10000 x 785)
Ytest = data['test_y']                          # (10000) (not one-hot encoding)

W = np.random.randn(10, 28*28+1)                # (10 x 785)

eta = 0.001
for t in range(100):
    loss = 0.
    num_correct_train = 0

    # Stochastic gradient descent.
    for x, y in zip(Xtrain, Ytrain):
        y_pred = softmax(np.dot(W, x))
        loss += -np.log(y_pred[np.argmax(y)])
        W += np.outer(eta * (y - y_pred), x)    # np.outer: out[i,j] = a[i]*b[j]
        if np.argmax(y_pred) == np.argmax(y):
            num_correct_train += 1

    # Evaluate and store the accuracy on the test set.
    num_correct_test = 0
    for x, y in zip(Xtest, Ytest):
        y_pred = np.argmax(np.dot(W, x))
        if y_pred == y:
            num_correct_test += 1

    print('#{}: loss={:.2f}, train_accuracy={:.4f}, test_accuracy={:.4f}'.format(
        t,
        loss / len(Ytrain),
        float(num_correct_train) / len(Ytrain),
        float(num_correct_test) / len(Ytest)
    ))
# Out:
# #0: loss=2.51, train_accuracy=0.6001, test_accuracy=0.7697
# #1: loss=1.03, train_accuracy=0.7879, test_accuracy=0.8258
# #2: loss=0.83, train_accuracy=0.8250, test_accuracy=0.8466
# #3: loss=0.73, train_accuracy=0.8423, test_accuracy=0.8577
# #4: loss=0.67, train_accuracy=0.8534, test_accuracy=0.8662
# #5: loss=0.62, train_accuracy=0.8615, test_accuracy=0.8719
# #6: loss=0.59, train_accuracy=0.8680, test_accuracy=0.8756
# #7: loss=0.56, train_accuracy=0.8725, test_accuracy=0.8780
# #8: loss=0.54, train_accuracy=0.8763, test_accuracy=0.8810
# #9: loss=0.52, train_accuracy=0.8792, test_accuracy=0.8839
# #10: loss=0.50, train_accuracy=0.8815, test_accuracy=0.8862
# #11: loss=0.49, train_accuracy=0.8840, test_accuracy=0.8873
# #12: loss=0.47, train_accuracy=0.8860, test_accuracy=0.8885
# #13: loss=0.46, train_accuracy=0.8881, test_accuracy=0.8899
# #14: loss=0.45, train_accuracy=0.8899, test_accuracy=0.8904
# #15: loss=0.44, train_accuracy=0.8914, test_accuracy=0.8916
# #16: loss=0.44, train_accuracy=0.8929, test_accuracy=0.8932
# #17: loss=0.43, train_accuracy=0.8940, test_accuracy=0.8947
# #18: loss=0.42, train_accuracy=0.8951, test_accuracy=0.8953
# #19: loss=0.41, train_accuracy=0.8963, test_accuracy=0.8964
# #20: loss=0.41, train_accuracy=0.8973, test_accuracy=0.8967
# #21: loss=0.40, train_accuracy=0.8982, test_accuracy=0.8973
# #22: loss=0.40, train_accuracy=0.8993, test_accuracy=0.8976
# #23: loss=0.39, train_accuracy=0.9000, test_accuracy=0.8980
# #24: loss=0.39, train_accuracy=0.9010, test_accuracy=0.8989
# #25: loss=0.38, train_accuracy=0.9019, test_accuracy=0.9002
# #26: loss=0.38, train_accuracy=0.9027, test_accuracy=0.9003
# #27: loss=0.37, train_accuracy=0.9033, test_accuracy=0.9012
# #28: loss=0.37, train_accuracy=0.9043, test_accuracy=0.9012
# #29: loss=0.37, train_accuracy=0.9050, test_accuracy=0.9019
# #30: loss=0.36, train_accuracy=0.9056, test_accuracy=0.9031
# #31: loss=0.36, train_accuracy=0.9062, test_accuracy=0.9036
# #32: loss=0.36, train_accuracy=0.9067, test_accuracy=0.9040
# #33: loss=0.35, train_accuracy=0.9071, test_accuracy=0.9051
# #34: loss=0.35, train_accuracy=0.9076, test_accuracy=0.9054
# #35: loss=0.35, train_accuracy=0.9083, test_accuracy=0.9060
# #36: loss=0.35, train_accuracy=0.9087, test_accuracy=0.9062
# #37: loss=0.34, train_accuracy=0.9093, test_accuracy=0.9066
# #38: loss=0.34, train_accuracy=0.9097, test_accuracy=0.9070
# #39: loss=0.34, train_accuracy=0.9103, test_accuracy=0.9071
# #40: loss=0.34, train_accuracy=0.9107, test_accuracy=0.9076
# #41: loss=0.34, train_accuracy=0.9110, test_accuracy=0.9078
# #42: loss=0.33, train_accuracy=0.9114, test_accuracy=0.9080
# #43: loss=0.33, train_accuracy=0.9118, test_accuracy=0.9085
# #44: loss=0.33, train_accuracy=0.9121, test_accuracy=0.9088
# #45: loss=0.33, train_accuracy=0.9126, test_accuracy=0.9092
# #46: loss=0.33, train_accuracy=0.9130, test_accuracy=0.9095
# #47: loss=0.32, train_accuracy=0.9133, test_accuracy=0.9099
# #48: loss=0.32, train_accuracy=0.9136, test_accuracy=0.9106
# #49: loss=0.32, train_accuracy=0.9143, test_accuracy=0.9113
# #50: loss=0.32, train_accuracy=0.9145, test_accuracy=0.9117
# #51: loss=0.32, train_accuracy=0.9149, test_accuracy=0.9124
# #52: loss=0.32, train_accuracy=0.9153, test_accuracy=0.9125
# #53: loss=0.31, train_accuracy=0.9156, test_accuracy=0.9125
# #54: loss=0.31, train_accuracy=0.9159, test_accuracy=0.9126
# #55: loss=0.31, train_accuracy=0.9164, test_accuracy=0.9127
# #56: loss=0.31, train_accuracy=0.9168, test_accuracy=0.9127
# #57: loss=0.31, train_accuracy=0.9171, test_accuracy=0.9130
# #58: loss=0.31, train_accuracy=0.9174, test_accuracy=0.9132
# #59: loss=0.31, train_accuracy=0.9176, test_accuracy=0.9131
# #60: loss=0.31, train_accuracy=0.9179, test_accuracy=0.9132
# #61: loss=0.30, train_accuracy=0.9182, test_accuracy=0.9132
# #62: loss=0.30, train_accuracy=0.9183, test_accuracy=0.9131
# #63: loss=0.30, train_accuracy=0.9186, test_accuracy=0.9136
# #64: loss=0.30, train_accuracy=0.9188, test_accuracy=0.9133
# #65: loss=0.30, train_accuracy=0.9191, test_accuracy=0.9131
# #66: loss=0.30, train_accuracy=0.9195, test_accuracy=0.9132
# #67: loss=0.30, train_accuracy=0.9197, test_accuracy=0.9136
# #68: loss=0.30, train_accuracy=0.9200, test_accuracy=0.9138
# #69: loss=0.30, train_accuracy=0.9203, test_accuracy=0.9140
# #70: loss=0.30, train_accuracy=0.9203, test_accuracy=0.9139
# #71: loss=0.29, train_accuracy=0.9205, test_accuracy=0.9140
# #72: loss=0.29, train_accuracy=0.9207, test_accuracy=0.9142
# #73: loss=0.29, train_accuracy=0.9209, test_accuracy=0.9143
# #74: loss=0.29, train_accuracy=0.9211, test_accuracy=0.9142
# #75: loss=0.29, train_accuracy=0.9212, test_accuracy=0.9140
# #76: loss=0.29, train_accuracy=0.9214, test_accuracy=0.9141
# #77: loss=0.29, train_accuracy=0.9215, test_accuracy=0.9145
# #78: loss=0.29, train_accuracy=0.9217, test_accuracy=0.9145
# #79: loss=0.29, train_accuracy=0.9220, test_accuracy=0.9142
# #80: loss=0.29, train_accuracy=0.9222, test_accuracy=0.9141
# #81: loss=0.29, train_accuracy=0.9224, test_accuracy=0.9142
# #82: loss=0.29, train_accuracy=0.9224, test_accuracy=0.9144
# #83: loss=0.29, train_accuracy=0.9227, test_accuracy=0.9146
# #84: loss=0.28, train_accuracy=0.9228, test_accuracy=0.9147
# #85: loss=0.28, train_accuracy=0.9230, test_accuracy=0.9148
# #86: loss=0.28, train_accuracy=0.9232, test_accuracy=0.9149
# #87: loss=0.28, train_accuracy=0.9234, test_accuracy=0.9148
# #88: loss=0.28, train_accuracy=0.9236, test_accuracy=0.9150
# #89: loss=0.28, train_accuracy=0.9238, test_accuracy=0.9150
# #90: loss=0.28, train_accuracy=0.9240, test_accuracy=0.9150
# #91: loss=0.28, train_accuracy=0.9241, test_accuracy=0.9154
# #92: loss=0.28, train_accuracy=0.9244, test_accuracy=0.9155
# #93: loss=0.28, train_accuracy=0.9246, test_accuracy=0.9156
# #94: loss=0.28, train_accuracy=0.9247, test_accuracy=0.9156
# #95: loss=0.28, train_accuracy=0.9249, test_accuracy=0.9156
# #96: loss=0.28, train_accuracy=0.9250, test_accuracy=0.9153
# #97: loss=0.28, train_accuracy=0.9252, test_accuracy=0.9155
# #98: loss=0.28, train_accuracy=0.9253, test_accuracy=0.9157
# #99: loss=0.28, train_accuracy=0.9254, test_accuracy=0.9158

# %% [markdown]
# ## Training with pytorch

# %% [markdown]
# ### Activate TensorBoard
#
# Usage from PyTorch: https://pytorch.org/docs/stable/tensorboard.html

# %%
# Uncomment these lines when you use TensorBoard.
#%load_ext tensorboard
#%tensorboard --logdir ./runs/

# %% [markdown]
# ### Convert the numpy arrays into pytorch tensor

# %%
def create_dataset(x, y, flatten=False):
    if flatten:
        # Convert it into a matrix (N [samples], 28*28 [dims])
        xt = torch.from_numpy(x).view(len(x), -1)
    else:
        # Convert it into a 4D tensor (N [samples], 1 [ch], 28 [px], 28 [px])
        xt = torch.from_numpy(x).unsqueeze(1)
    yt = torch.from_numpy(y).long()
    return TensorDataset(xt, yt)

def test_model(model, loss_fn, test_loader, device):
    model.eval()

    loss = 0.
    num_correct = 0.
    for batch_idx, (x, y) in enumerate(test_loader):
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        loss += loss_fn(y_pred, y).item()
        _, predicted = torch.max(y_pred.data, 1)
        num_correct += (predicted == y).sum().item()

    model.train()
    loss /= len(test_loader.dataset)
    num_correct /= len(test_loader.dataset)
    return loss, num_correct

# %% [markdown]
# ### Single-layer neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

model = nn.Sequential()
model.add_module('fc1', nn.Linear(784, 10, bias=True))
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

writer = SummaryWriter(comment="single-layer")
for t in range(100):
    train_loss = 0.
    train_correct = 0

    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()

        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))

    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Record loss and accuracy values on the training and test sets.
    writer.add_scalars('loss', {'train': train_loss, 'test': test_loss}, t)
    writer.add_scalars('accuracy', {'train': train_correct, 'test': test_correct}, t)

    # Report progress (comment out the following line when you use TensorBoard).
    print('#{}: loss_test={:.4f}, loss_train={:.4f}, acc_test={:.4f}, acc_train={:.4f}'.format(
        t,
        test_loss,
        train_loss,
        test_correct,
        train_correct
    ))
writer.close()
# Out:
# Sequential(
#   (fc1): Linear(in_features=784, out_features=10, bias=True)
# )
# #0: loss_test=0.0164, loss_train=0.0086, acc_test=0.4654, acc_train=0.2778
# #1: loss_test=0.0149, loss_train=0.0078, acc_test=0.6643, acc_train=0.5715
# #2: loss_test=0.0136, loss_train=0.0071, acc_test=0.7185, acc_train=0.6871
# #3: loss_test=0.0125, loss_train=0.0065, acc_test=0.7476, acc_train=0.7268
# #4: loss_test=0.0116, loss_train=0.0060, acc_test=0.7703, acc_train=0.7480
# #5: loss_test=0.0108, loss_train=0.0056, acc_test=0.7849, acc_train=0.7644
# #6: loss_test=0.0101, loss_train=0.0053, acc_test=0.7949, acc_train=0.7764
# #7: loss_test=0.0096, loss_train=0.0050, acc_test=0.8008, acc_train=0.7858
# #8: loss_test=0.0091, loss_train=0.0047, acc_test=0.8079, acc_train=0.7939
# #9: loss_test=0.0087, loss_train=0.0045, acc_test=0.8144, acc_train=0.8002
# #10: loss_test=0.0083, loss_train=0.0043, acc_test=0.8197, acc_train=0.8055
# #11: loss_test=0.0080, loss_train=0.0041, acc_test=0.8225, acc_train=0.8105
# #12: loss_test=0.0077, loss_train=0.0040, acc_test=0.8258, acc_train=0.8149
# #13: loss_test=0.0074, loss_train=0.0038, acc_test=0.8286, acc_train=0.8186
# #14: loss_test=0.0072, loss_train=0.0037, acc_test=0.8329, acc_train=0.8215
# #15: loss_test=0.0070, loss_train=0.0036, acc_test=0.8353, acc_train=0.8250
# #16: loss_test=0.0068, loss_train=0.0035, acc_test=0.8383, acc_train=0.8276
# #17: loss_test=0.0066, loss_train=0.0034, acc_test=0.8406, acc_train=0.8302
# #18: loss_test=0.0065, loss_train=0.0033, acc_test=0.8427, acc_train=0.8322
# #19: loss_test=0.0063, loss_train=0.0033, acc_test=0.8445, acc_train=0.8341
# #20: loss_test=0.0062, loss_train=0.0032, acc_test=0.8465, acc_train=0.8361
# #21: loss_test=0.0061, loss_train=0.0031, acc_test=0.8479, acc_train=0.8379
# #22: loss_test=0.0059, loss_train=0.0031, acc_test=0.8493, acc_train=0.8397
# #23: loss_test=0.0058, loss_train=0.0030, acc_test=0.8504, acc_train=0.8413
# #24: loss_test=0.0057, loss_train=0.0030, acc_test=0.8523, acc_train=0.8426
# #25: loss_test=0.0056, loss_train=0.0029, acc_test=0.8541, acc_train=0.8438
# #26: loss_test=0.0055, loss_train=0.0029, acc_test=0.8559, acc_train=0.8451
# #27: loss_test=0.0055, loss_train=0.0028, acc_test=0.8570, acc_train=0.8466
# #28: loss_test=0.0054, loss_train=0.0028, acc_test=0.8580, acc_train=0.8479
# #29: loss_test=0.0053, loss_train=0.0028, acc_test=0.8593, acc_train=0.8492
# #30: loss_test=0.0052, loss_train=0.0027, acc_test=0.8602, acc_train=0.8501
# #31: loss_test=0.0052, loss_train=0.0027, acc_test=0.8609, acc_train=0.8515
# #32: loss_test=0.0051, loss_train=0.0027, acc_test=0.8618, acc_train=0.8522
# #33: loss_test=0.0050, loss_train=0.0026, acc_test=0.8626, acc_train=0.8533
# #34: loss_test=0.0050, loss_train=0.0026, acc_test=0.8635, acc_train=0.8541
# #35: loss_test=0.0049, loss_train=0.0026, acc_test=0.8643, acc_train=0.8548
# #36: loss_test=0.0049, loss_train=0.0025, acc_test=0.8653, acc_train=0.8557
# #37: loss_test=0.0048, loss_train=0.0025, acc_test=0.8658, acc_train=0.8565
# #38: loss_test=0.0048, loss_train=0.0025, acc_test=0.8660, acc_train=0.8574
# #39: loss_test=0.0047, loss_train=0.0025, acc_test=0.8666, acc_train=0.8580
# #40: loss_test=0.0047, loss_train=0.0024, acc_test=0.8669, acc_train=0.8585
# #41: loss_test=0.0047, loss_train=0.0024, acc_test=0.8674, acc_train=0.8592
# #42: loss_test=0.0046, loss_train=0.0024, acc_test=0.8686, acc_train=0.8598
# #43: loss_test=0.0046, loss_train=0.0024, acc_test=0.8694, acc_train=0.8605
# #44: loss_test=0.0045, loss_train=0.0024, acc_test=0.8698, acc_train=0.8611
# #45: loss_test=0.0045, loss_train=0.0023, acc_test=0.8702, acc_train=0.8617
# #46: loss_test=0.0045, loss_train=0.0023, acc_test=0.8705, acc_train=0.8621
# #47: loss_test=0.0044, loss_train=0.0023, acc_test=0.8709, acc_train=0.8625
# #48: loss_test=0.0044, loss_train=0.0023, acc_test=0.8721, acc_train=0.8631
# #49: loss_test=0.0044, loss_train=0.0023, acc_test=0.8727, acc_train=0.8636
# #50: loss_test=0.0043, loss_train=0.0023, acc_test=0.8738, acc_train=0.8641
# #51: loss_test=0.0043, loss_train=0.0022, acc_test=0.8746, acc_train=0.8645
# #52: loss_test=0.0043, loss_train=0.0022, acc_test=0.8749, acc_train=0.8650
# #53: loss_test=0.0043, loss_train=0.0022, acc_test=0.8754, acc_train=0.8653
# #54: loss_test=0.0042, loss_train=0.0022, acc_test=0.8755, acc_train=0.8657
# #55: loss_test=0.0042, loss_train=0.0022, acc_test=0.8757, acc_train=0.8663
# #56: loss_test=0.0042, loss_train=0.0022, acc_test=0.8764, acc_train=0.8665
# #57: loss_test=0.0042, loss_train=0.0022, acc_test=0.8771, acc_train=0.8670
# #58: loss_test=0.0041, loss_train=0.0022, acc_test=0.8777, acc_train=0.8674
# #59: loss_test=0.0041, loss_train=0.0021, acc_test=0.8779, acc_train=0.8680
# #60: loss_test=0.0041, loss_train=0.0021, acc_test=0.8780, acc_train=0.8683
# #61: loss_test=0.0041, loss_train=0.0021, acc_test=0.8783, acc_train=0.8690
# #62: loss_test=0.0040, loss_train=0.0021, acc_test=0.8786, acc_train=0.8691
# #63: loss_test=0.0040, loss_train=0.0021, acc_test=0.8785, acc_train=0.8695
# #64: loss_test=0.0040, loss_train=0.0021, acc_test=0.8788, acc_train=0.8699
# #65: loss_test=0.0040, loss_train=0.0021, acc_test=0.8789, acc_train=0.8702
# #66: loss_test=0.0040, loss_train=0.0021, acc_test=0.8790, acc_train=0.8704
# #67: loss_test=0.0039, loss_train=0.0021, acc_test=0.8792, acc_train=0.8706
# #68: loss_test=0.0039, loss_train=0.0021, acc_test=0.8792, acc_train=0.8712
# #69: loss_test=0.0039, loss_train=0.0020, acc_test=0.8795, acc_train=0.8715
# #70: loss_test=0.0039, loss_train=0.0020, acc_test=0.8796, acc_train=0.8720
# #71: loss_test=0.0039, loss_train=0.0020, acc_test=0.8798, acc_train=0.8724
# #72: loss_test=0.0039, loss_train=0.0020, acc_test=0.8804, acc_train=0.8727
# #73: loss_test=0.0038, loss_train=0.0020, acc_test=0.8809, acc_train=0.8730
# #74: loss_test=0.0038, loss_train=0.0020, acc_test=0.8810, acc_train=0.8733
# #75: loss_test=0.0038, loss_train=0.0020, acc_test=0.8813, acc_train=0.8737
# #76: loss_test=0.0038, loss_train=0.0020, acc_test=0.8815, acc_train=0.8739
# #77: loss_test=0.0038, loss_train=0.0020, acc_test=0.8815, acc_train=0.8742
# #78: loss_test=0.0038, loss_train=0.0020, acc_test=0.8821, acc_train=0.8745
# #79: loss_test=0.0038, loss_train=0.0020, acc_test=0.8823, acc_train=0.8746
# #80: loss_test=0.0037, loss_train=0.0020, acc_test=0.8823, acc_train=0.8751
# #81: loss_test=0.0037, loss_train=0.0019, acc_test=0.8824, acc_train=0.8753
# #82: loss_test=0.0037, loss_train=0.0019, acc_test=0.8828, acc_train=0.8757
# #83: loss_test=0.0037, loss_train=0.0019, acc_test=0.8831, acc_train=0.8760
# #84: loss_test=0.0037, loss_train=0.0019, acc_test=0.8835, acc_train=0.8762
# #85: loss_test=0.0037, loss_train=0.0019, acc_test=0.8837, acc_train=0.8764
# #86: loss_test=0.0037, loss_train=0.0019, acc_test=0.8838, acc_train=0.8767
# #87: loss_test=0.0037, loss_train=0.0019, acc_test=0.8842, acc_train=0.8769
# #88: loss_test=0.0036, loss_train=0.0019, acc_test=0.8846, acc_train=0.8774
# #89: loss_test=0.0036, loss_train=0.0019, acc_test=0.8851, acc_train=0.8776
# #90: loss_test=0.0036, loss_train=0.0019, acc_test=0.8853, acc_train=0.8776
# #91: loss_test=0.0036, loss_train=0.0019, acc_test=0.8854, acc_train=0.8780
# #92: loss_test=0.0036, loss_train=0.0019, acc_test=0.8859, acc_train=0.8782
# #93: loss_test=0.0036, loss_train=0.0019, acc_test=0.8865, acc_train=0.8785
# #94: loss_test=0.0036, loss_train=0.0019, acc_test=0.8865, acc_train=0.8789
# #95: loss_test=0.0036, loss_train=0.0019, acc_test=0.8869, acc_train=0.8789
# #96: loss_test=0.0036, loss_train=0.0019, acc_test=0.8869, acc_train=0.8791
# #97: loss_test=0.0035, loss_train=0.0019, acc_test=0.8873, acc_train=0.8794
# #98: loss_test=0.0035, loss_train=0.0018, acc_test=0.8877, acc_train=0.8796
# #99: loss_test=0.0035, loss_train=0.0018, acc_test=0.8879, acc_train=0.8799

# %% [markdown]
# ### Three-layer neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

model = nn.Sequential()
model.add_module('fc1',      nn.Linear(784, 256))
model.add_module('relu1',    nn.ReLU())
model.add_module('dropout1', nn.Dropout())
model.add_module('fc2',      nn.Linear(256, 256))
model.add_module('relu2',    nn.ReLU())
model.add_module('dropout2', nn.Dropout())
model.add_module('fc3',      nn.Linear(256, 10))
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'], flatten=True)
test_set = create_dataset(data['test_x'], data['test_y'], flatten=True)
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

writer = SummaryWriter(comment="two-layer")
for t in range(100):
    train_loss = 0.
    train_correct = 0

    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()

        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))

    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Record loss and accuracy values on the training and test sets.
    writer.add_scalars('loss', {'train': train_loss, 'test': test_loss}, t)
    writer.add_scalars('accuracy', {'train': train_correct, 'test': test_correct}, t)

    # Report progress (comment out the following line when you use TensorBoard).
    print('#{}: loss_test={:.4f}, loss_train={:.4f}, acc_test={:.4f}, acc_train={:.4f}'.format(
        t,
        test_loss,
        train_loss,
        test_correct,
        train_correct
    ))

writer.close()
# Out:
# Sequential(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )
# #0: loss_test=0.0181, loss_train=0.0090, acc_test=0.1283, acc_train=0.1023
# #1: loss_test=0.0181, loss_train=0.0090, acc_test=0.1678, acc_train=0.1152
# #2: loss_test=0.0180, loss_train=0.0090, acc_test=0.2132, acc_train=0.1326
# #3: loss_test=0.0180, loss_train=0.0089, acc_test=0.2656, acc_train=0.1523
# #4: loss_test=0.0179, loss_train=0.0089, acc_test=0.3163, acc_train=0.1692
# #5: loss_test=0.0178, loss_train=0.0089, acc_test=0.3664, acc_train=0.1883
# #6: loss_test=0.0177, loss_train=0.0088, acc_test=0.4053, acc_train=0.2110
# #7: loss_test=0.0176, loss_train=0.0088, acc_test=0.4381, acc_train=0.2294
# #8: loss_test=0.0175, loss_train=0.0088, acc_test=0.4703, acc_train=0.2527
# #9: loss_test=0.0174, loss_train=0.0087, acc_test=0.4981, acc_train=0.2769
# #10: loss_test=0.0173, loss_train=0.0087, acc_test=0.5251, acc_train=0.2938
# #11: loss_test=0.0171, loss_train=0.0086, acc_test=0.5434, acc_train=0.3135
# #12: loss_test=0.0170, loss_train=0.0085, acc_test=0.5597, acc_train=0.3352
# #13: loss_test=0.0168, loss_train=0.0085, acc_test=0.5729, acc_train=0.3546
# #14: loss_test=0.0166, loss_train=0.0084, acc_test=0.5829, acc_train=0.3770
# #15: loss_test=0.0164, loss_train=0.0083, acc_test=0.5950, acc_train=0.3962
# #16: loss_test=0.0161, loss_train=0.0082, acc_test=0.6108, acc_train=0.4178
# #17: loss_test=0.0158, loss_train=0.0081, acc_test=0.6289, acc_train=0.4358
# #18: loss_test=0.0155, loss_train=0.0079, acc_test=0.6462, acc_train=0.4581
# #19: loss_test=0.0151, loss_train=0.0078, acc_test=0.6589, acc_train=0.4788
# #20: loss_test=0.0147, loss_train=0.0076, acc_test=0.6732, acc_train=0.4983
# #21: loss_test=0.0143, loss_train=0.0075, acc_test=0.6842, acc_train=0.5167
# #22: loss_test=0.0139, loss_train=0.0073, acc_test=0.6940, acc_train=0.5339
# #23: loss_test=0.0134, loss_train=0.0071, acc_test=0.7021, acc_train=0.5429
# #24: loss_test=0.0129, loss_train=0.0069, acc_test=0.7100, acc_train=0.5575
# #25: loss_test=0.0123, loss_train=0.0066, acc_test=0.7148, acc_train=0.5668
# #26: loss_test=0.0118, loss_train=0.0064, acc_test=0.7206, acc_train=0.5760
# #27: loss_test=0.0112, loss_train=0.0062, acc_test=0.7265, acc_train=0.5858
# #28: loss_test=0.0107, loss_train=0.0060, acc_test=0.7339, acc_train=0.5940
# #29: loss_test=0.0102, loss_train=0.0057, acc_test=0.7414, acc_train=0.6012
# #30: loss_test=0.0097, loss_train=0.0055, acc_test=0.7503, acc_train=0.6112
# #31: loss_test=0.0093, loss_train=0.0053, acc_test=0.7580, acc_train=0.6172
# #32: loss_test=0.0089, loss_train=0.0052, acc_test=0.7659, acc_train=0.6243
# #33: loss_test=0.0085, loss_train=0.0050, acc_test=0.7740, acc_train=0.6325
# #34: loss_test=0.0081, loss_train=0.0048, acc_test=0.7792, acc_train=0.6410
# #35: loss_test=0.0078, loss_train=0.0047, acc_test=0.7839, acc_train=0.6506
# #36: loss_test=0.0075, loss_train=0.0045, acc_test=0.7889, acc_train=0.6578
# #37: loss_test=0.0073, loss_train=0.0044, acc_test=0.7934, acc_train=0.6623
# #38: loss_test=0.0070, loss_train=0.0043, acc_test=0.7971, acc_train=0.6709
# #39: loss_test=0.0068, loss_train=0.0042, acc_test=0.8007, acc_train=0.6761
# #40: loss_test=0.0066, loss_train=0.0041, acc_test=0.8052, acc_train=0.6824
# #41: loss_test=0.0064, loss_train=0.0040, acc_test=0.8084, acc_train=0.6874
# #42: loss_test=0.0063, loss_train=0.0039, acc_test=0.8117, acc_train=0.6915
# #43: loss_test=0.0061, loss_train=0.0039, acc_test=0.8137, acc_train=0.6985
# #44: loss_test=0.0060, loss_train=0.0038, acc_test=0.8176, acc_train=0.7059
# #45: loss_test=0.0058, loss_train=0.0037, acc_test=0.8195, acc_train=0.7085
# #46: loss_test=0.0057, loss_train=0.0037, acc_test=0.8227, acc_train=0.7125
# #47: loss_test=0.0056, loss_train=0.0036, acc_test=0.8256, acc_train=0.7172
# #48: loss_test=0.0055, loss_train=0.0035, acc_test=0.8275, acc_train=0.7241
# #49: loss_test=0.0054, loss_train=0.0035, acc_test=0.8297, acc_train=0.7252
# #50: loss_test=0.0053, loss_train=0.0034, acc_test=0.8318, acc_train=0.7313
# #51: loss_test=0.0052, loss_train=0.0034, acc_test=0.8339, acc_train=0.7335
# #52: loss_test=0.0051, loss_train=0.0033, acc_test=0.8362, acc_train=0.7373
# #53: loss_test=0.0050, loss_train=0.0033, acc_test=0.8387, acc_train=0.7408
# #54: loss_test=0.0049, loss_train=0.0032, acc_test=0.8398, acc_train=0.7446
# #55: loss_test=0.0048, loss_train=0.0032, acc_test=0.8421, acc_train=0.7487
# #56: loss_test=0.0048, loss_train=0.0032, acc_test=0.8450, acc_train=0.7515
# #57: loss_test=0.0047, loss_train=0.0031, acc_test=0.8459, acc_train=0.7559
# #58: loss_test=0.0046, loss_train=0.0031, acc_test=0.8478, acc_train=0.7590
# #59: loss_test=0.0046, loss_train=0.0030, acc_test=0.8486, acc_train=0.7602
# #60: loss_test=0.0045, loss_train=0.0030, acc_test=0.8501, acc_train=0.7645
# #61: loss_test=0.0045, loss_train=0.0030, acc_test=0.8525, acc_train=0.7674
# #62: loss_test=0.0044, loss_train=0.0029, acc_test=0.8539, acc_train=0.7693
# #63: loss_test=0.0044, loss_train=0.0029, acc_test=0.8554, acc_train=0.7700
# #64: loss_test=0.0043, loss_train=0.0029, acc_test=0.8567, acc_train=0.7725
# #65: loss_test=0.0043, loss_train=0.0029, acc_test=0.8584, acc_train=0.7753
# #66: loss_test=0.0042, loss_train=0.0028, acc_test=0.8597, acc_train=0.7805
# #67: loss_test=0.0042, loss_train=0.0028, acc_test=0.8606, acc_train=0.7823
# #68: loss_test=0.0041, loss_train=0.0028, acc_test=0.8625, acc_train=0.7852
# #69: loss_test=0.0041, loss_train=0.0027, acc_test=0.8640, acc_train=0.7836
# #70: loss_test=0.0040, loss_train=0.0027, acc_test=0.8649, acc_train=0.7885
# #71: loss_test=0.0040, loss_train=0.0027, acc_test=0.8660, acc_train=0.7883
# #72: loss_test=0.0040, loss_train=0.0027, acc_test=0.8666, acc_train=0.7909
# #73: loss_test=0.0039, loss_train=0.0026, acc_test=0.8686, acc_train=0.7945
# #74: loss_test=0.0039, loss_train=0.0026, acc_test=0.8687, acc_train=0.7954
# #75: loss_test=0.0038, loss_train=0.0026, acc_test=0.8695, acc_train=0.7974
# #76: loss_test=0.0038, loss_train=0.0026, acc_test=0.8702, acc_train=0.8026
# #77: loss_test=0.0038, loss_train=0.0026, acc_test=0.8713, acc_train=0.8004
# #78: loss_test=0.0037, loss_train=0.0025, acc_test=0.8723, acc_train=0.8020
# #79: loss_test=0.0037, loss_train=0.0025, acc_test=0.8735, acc_train=0.8040
# #80: loss_test=0.0037, loss_train=0.0025, acc_test=0.8748, acc_train=0.8053
# #81: loss_test=0.0037, loss_train=0.0025, acc_test=0.8755, acc_train=0.8079
# #82: loss_test=0.0036, loss_train=0.0025, acc_test=0.8769, acc_train=0.8100
# #83: loss_test=0.0036, loss_train=0.0025, acc_test=0.8776, acc_train=0.8087
# #84: loss_test=0.0036, loss_train=0.0024, acc_test=0.8787, acc_train=0.8146
# #85: loss_test=0.0035, loss_train=0.0024, acc_test=0.8791, acc_train=0.8138
# #86: loss_test=0.0035, loss_train=0.0024, acc_test=0.8802, acc_train=0.8145
# #87: loss_test=0.0035, loss_train=0.0024, acc_test=0.8808, acc_train=0.8165
# #88: loss_test=0.0035, loss_train=0.0024, acc_test=0.8810, acc_train=0.8172
# #89: loss_test=0.0034, loss_train=0.0024, acc_test=0.8815, acc_train=0.8191
# #90: loss_test=0.0034, loss_train=0.0023, acc_test=0.8816, acc_train=0.8199
# #91: loss_test=0.0034, loss_train=0.0023, acc_test=0.8823, acc_train=0.8207
# #92: loss_test=0.0034, loss_train=0.0023, acc_test=0.8830, acc_train=0.8226
# #93: loss_test=0.0034, loss_train=0.0023, acc_test=0.8833, acc_train=0.8239
# #94: loss_test=0.0033, loss_train=0.0023, acc_test=0.8841, acc_train=0.8238
# #95: loss_test=0.0033, loss_train=0.0023, acc_test=0.8852, acc_train=0.8257
# #96: loss_test=0.0033, loss_train=0.0023, acc_test=0.8856, acc_train=0.8278
# #97: loss_test=0.0033, loss_train=0.0023, acc_test=0.8861, acc_train=0.8284
# #98: loss_test=0.0033, loss_train=0.0022, acc_test=0.8873, acc_train=0.8298
# #99: loss_test=0.0032, loss_train=0.0022, acc_test=0.8875, acc_train=0.8303

# %% [markdown]
# ### Convolutional Neural Network (CNN)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np

#device = torch.device("cpu") # Uncomment this to run on CPU
device = torch.device("cuda:0") # Uncomment this to run on GPU

class Flatten(torch.nn.Module):
    def __init__(self):
        super(Flatten, self).__init__()

    def forward(self, x):
        return x.view(-1, 512)

model = torch.nn.Sequential(
    torch.nn.Conv2d(1, 16, (5, 5)),
    torch.nn.MaxPool2d(2),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    torch.nn.Conv2d(16, 32, (5, 5)),
    torch.nn.MaxPool2d(2),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    Flatten(),
    torch.nn.Linear(512, 256),
    torch.nn.ReLU(),
    torch.nn.Dropout(),
    torch.nn.Linear(256, 10),
)
print(model)
model.to(device)

data = np.load('mnist.npz')
train_set = create_dataset(data['train_x'], data['train_y'])
test_set = create_dataset(data['test_x'], data['test_y'])
train_loader = DataLoader(train_set, batch_size=256, shuffle=True)
test_loader = DataLoader(test_set, batch_size=128)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

writer = SummaryWriter(comment="CNN")
for t in range(100):
    train_loss = 0.
    train_correct = 0

    # Training loop for mini-batches
    for batch_idx, (x, y) in enumerate(train_loader):
        # Make predictions with the current parameters.
        x, y = x.to(device), y.to(device)
        y_pred = model(x)
        _, predicted = torch.max(y_pred.data, 1)
        train_correct += (predicted == y).sum().item()

        # Compute the loss value.
        loss = loss_fn(y_pred, y)
        train_loss += loss.item()

        # Update the parameters.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Compute the average loss and accuracy.
    train_loss /= len(train_loader.dataset)
    train_correct /= float(len(train_loader.dataset))

    # Evaluate the model on the test set.
    test_loss, test_correct = test_model(model, loss_fn, test_loader, device)

    # Record loss and accuracy values on the training and test sets.
    writer.add_scalars('loss', {'train': train_loss, 'test': test_loss}, t)
    writer.add_scalars('accuracy', {'train': train_correct, 'test': test_correct}, t)

    # Report progress (comment out the following line when you use TensorBoard).
    print('#{}: loss_test={:.4f}, loss_train={:.4f}, acc_test={:.4f}, acc_train={:.4f}'.format(
        t,
        test_loss,
        train_loss,
        test_correct,
        train_correct
    ))

writer.close()
# Out:
# Sequential(
#   (0): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1))
#   (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (2): ReLU()
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): ReLU()
#   (7): Dropout(p=0.5, inplace=False)
#   (8): Flatten()
#   (9): Linear(in_features=512, out_features=256, bias=True)
#   (10): ReLU()
#   (11): Dropout(p=0.5, inplace=False)
#   (12): Linear(in_features=256, out_features=10, bias=True)
# )
# #0: loss_test=0.0182, loss_train=0.0090, acc_test=0.1161, acc_train=0.1057
# #1: loss_test=0.0181, loss_train=0.0090, acc_test=0.1435, acc_train=0.1124
# #2: loss_test=0.0181, loss_train=0.0090, acc_test=0.1890, acc_train=0.1218
# #3: loss_test=0.0181, loss_train=0.0090, acc_test=0.2468, acc_train=0.1277
# #4: loss_test=0.0180, loss_train=0.0090, acc_test=0.3076, acc_train=0.1334
# #5: loss_test=0.0180, loss_train=0.0089, acc_test=0.3585, acc_train=0.1394
# #6: loss_test=0.0180, loss_train=0.0089, acc_test=0.4175, acc_train=0.1510
# #7: loss_test=0.0179, loss_train=0.0089, acc_test=0.4664, acc_train=0.1607
# #8: loss_test=0.0178, loss_train=0.0089, acc_test=0.5082, acc_train=0.1689
# #9: loss_test=0.0177, loss_train=0.0088, acc_test=0.5368, acc_train=0.1789
# #10: loss_test=0.0176, loss_train=0.0088, acc_test=0.5675, acc_train=0.1902
